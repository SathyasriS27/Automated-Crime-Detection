# %%
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        # !pip install --upgrade imutils
# Out:
# Requirement already up-to-date: imutils in c:\users\yash umale\appdata\local\programs\python\python39\lib\site-packages (0.5.4)
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\users\yash umale\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in c:\users\yash umale\appdata\local\programs\python\python39\lib\site-packages (4.5.1.48)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\yash umale\appdata\local\programs\python\python39\lib\site-packages (from opencv-contrib-python) (1.20.1)
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\users\yash umale\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# # **Extract embeddings from face dataset**

# %%
# Importing all necessary packages

from imutils import paths
import numpy as np
import argparse
import imutils
import pickle
import time
import cv2
import os
from keras.models import model_from_json
from tensorflow import keras
from tf_models.inception_resnet_v1 import *
import json
from keras.preprocessing.image import load_img, save_img, img_to_array
from keras.applications.imagenet_utils import preprocess_input

# %%
# Load face detector
from tf_models.inception_resnet_v1 import *

print("Loading face detector...")

protoPath = os.path.sep.join([r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\opencv-face-recognition\face_detection_model', 'deploy.prototxt'])
modelPath = os.path.sep.join([r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\opencv-face-recognition\face_detection_model', 'res10_300x300_ssd_iter_140000.caffemodel'])

detector = cv2.dnn.readNetFromCaffe(protoPath, modelPath)


# Load face recognizer

print("\nLoading face recognizer...")
embedder = InceptionResNetV1()
# embedder = model_from_json(open(r"C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\New TF Model Test\Model\facenet_model.json", "r").read())
embedder.load_weights('facenet_weights.h5')
# embedder.save(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\tf_models\facenet_embedder')
# embedder = cv2.dnn.readNetFromTorch(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\opencv-face-recognition\openface_nn4.small2.v1.t7')

def preprocess_image(image_path):
    img = load_img(image_path, target_size=(160, 160))
    # img = img_to_array(img)
    # img = np.expand_dims(img, axis=0)
    img = preprocess_input(img)
    return img

def preprocess_image_img(img):
    img = cv2.resize(img, (160, 160))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = preprocess_input(img)
    return img
# Out:
# Loading face detector...
#
# Loading face recognizer...

# %%
# Entering paths to our images dataset

print('\nQuantifying faces...')
imagePaths = list(paths.list_images(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\Datasets'))

knownEmbeddings = []
knownNames = []

# Total number of faces
total = 0
# Out:
# Quantifying faces...

# %%
# Loop over all image paths

for (i, imagePath) in enumerate(imagePaths):
  print("Processing image {}/{}".format(i + 1, len(imagePaths)))                  # Extract the person name from the image path
  name = imagePath.split(os.path.sep)[-2]

  image = cv2.imread(imagePath)                                                   # Load the image
  image = imutils.resize(image, width=600)                                        # Resize to (600, 600)
  (h, w) = image.shape[:2]                                                        # Store image dimensions
  imageBlob = cv2.dnn.blobFromImage(                                              # Construct a blob from the image
  	cv2.resize(image, (300, 300)), 1.0, (300, 300),
  	(104.0, 177.0, 123.0), swapRB=False, crop=False)

  detector.setInput(imageBlob)                                                    # Face Detector to localize face in an image
  detections = detector.forward()       

  if len(detections) > 0:                                                         # Ensure at least one face was found
    i = np.argmax(detections[0, 0, :, 2])
    confidence = detections[0, 0, i, 2]        

    if (confidence > 0.1):                                                          # Filtering weak detections
      box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
      (startX, startY, endX, endY) = box.astype("int")
			
      face = image[startY:endY, startX:endX]
      (fH, fW) = face.shape[:2]
			
      if (fW < 20 or fH < 20):
        continue    

      
      # faceBlob = cv2.dnn.blobFromImage(face, 1.0 / 255, (160, 160), (0, 0, 0), 
      #                                  swapRB=True, crop=False)                   # Create blob

      # embedder.setInput(faceBlob)
      vec = embedder.predict(preprocess_image_img(face))[0, :].reshape(1, -1)

      knownNames.append(name)                                                     # Append name to list
      knownEmbeddings.append(vec.flatten())                                       # Append flattened embedding to list
      total += 1
# Out:
# Processing image 1/1063
# Processing image 2/1063
# Processing image 3/1063
# Processing image 4/1063
# Processing image 5/1063
# Processing image 6/1063
# Processing image 7/1063
# Processing image 8/1063
# Processing image 9/1063
# Processing image 10/1063
# Processing image 11/1063
# Processing image 12/1063
# Processing image 13/1063
# Processing image 14/1063
# Processing image 15/1063
# Processing image 16/1063
# Processing image 17/1063
# Processing image 18/1063
# Processing image 19/1063
# Processing image 20/1063
# Processing image 21/1063
# Processing image 22/1063
# Processing image 23/1063
# Processing image 24/1063
# Processing image 25/1063
# Processing image 26/1063
# Processing image 27/1063
# Processing image 28/1063
# Processing image 29/1063
# Processing image 30/1063
# Processing image 31/1063
# Processing image 32/1063
# Processing image 33/1063
# Processing image 34/1063
# Processing image 35/1063
# Processing image 36/1063
# Processing image 37/1063
# Processing image 38/1063
# Processing image 39/1063
# Processing image 40/1063
# Processing image 41/1063
# Processing image 42/1063
# Processing image 43/1063
# Processing image 44/1063
# Processing image 45/1063
# Processing image 46/1063
# Processing image 47/1063
# Processing image 48/1063
# Processing image 49/1063
# Processing image 50/1063
# Processing image 51/1063
# Processing image 52/1063
# Processing image 53/1063
# Processing image 54/1063
# Processing image 55/1063
# Processing image 56/1063
# Processing image 57/1063
# Processing image 58/1063
# Processing image 59/1063
# Processing image 60/1063
# Processing image 61/1063
# Processing image 62/1063
# Processing image 63/1063
# Processing image 64/1063
# Processing image 65/1063
# Processing image 66/1063
# Processing image 67/1063
# Processing image 68/1063
# Processing image 69/1063
# Processing image 70/1063
# Processing image 71/1063
# Processing image 72/1063
# Processing image 73/1063
# Processing image 74/1063
# Processing image 75/1063
# Processing image 76/1063
# Processing image 77/1063
# Processing image 78/1063
# Processing image 79/1063
# Processing image 80/1063
# Processing image 81/1063
# Processing image 82/1063
# Processing image 83/1063
# Processing image 84/1063
# Processing image 85/1063
# Processing image 86/1063
# Processing image 87/1063
# Processing image 88/1063
# Processing image 89/1063
# Processing image 90/1063
# Processing image 91/1063
# Processing image 92/1063
# Processing image 93/1063
# Processing image 94/1063
# Processing image 95/1063
# Processing image 96/1063
# Processing image 97/1063
# Processing image 98/1063
# Processing image 99/1063
# Processing image 100/1063
# Processing image 101/1063
# Processing image 102/1063
# Processing image 103/1063
# Processing image 104/1063
# Processing image 105/1063
# Processing image 106/1063
# Processing image 107/1063
# Processing image 108/1063
# Processing image 109/1063
# Processing image 110/1063
# Processing image 111/1063
# Processing image 112/1063
# Processing image 113/1063
# Processing image 114/1063
# Processing image 115/1063
# Processing image 116/1063
# Processing image 117/1063
# Processing image 118/1063
# Processing image 119/1063
# Processing image 120/1063
# Processing image 121/1063
# Processing image 122/1063
# Processing image 123/1063
# Processing image 124/1063
# Processing image 125/1063
# Processing image 126/1063
# Processing image 127/1063
# Processing image 128/1063
# Processing image 129/1063
# Processing image 130/1063
# Processing image 131/1063
# Processing image 132/1063
# Processing image 133/1063
# Processing image 134/1063
# Processing image 135/1063
# Processing image 136/1063
# Processing image 137/1063
# Processing image 138/1063
# Processing image 139/1063
# Processing image 140/1063
# Processing image 141/1063
# Processing image 142/1063
# Processing image 143/1063
# Processing image 144/1063
# Processing image 145/1063
# Processing image 146/1063
# Processing image 147/1063
# Processing image 148/1063
# Processing image 149/1063
# Processing image 150/1063
# Processing image 151/1063
# Processing image 152/1063
# Processing image 153/1063
# Processing image 154/1063
# Processing image 155/1063
# Processing image 156/1063
# Processing image 157/1063
# Processing image 158/1063
# Processing image 159/1063
# Processing image 160/1063
# Processing image 161/1063
# Processing image 162/1063
# Processing image 163/1063
# Processing image 164/1063
# Processing image 165/1063
# Processing image 166/1063
# Processing image 167/1063
# Processing image 168/1063
# Processing image 169/1063
# Processing image 170/1063
# Processing image 171/1063
# Processing image 172/1063
# Processing image 173/1063
# Processing image 174/1063
# Processing image 175/1063
# Processing image 176/1063
# Processing image 177/1063
# Processing image 178/1063
# Processing image 179/1063
# Processing image 180/1063
# Processing image 181/1063
# Processing image 182/1063
# Processing image 183/1063
# Processing image 184/1063
# Processing image 185/1063
# Processing image 186/1063
# Processing image 187/1063
# Processing image 188/1063
# Processing image 189/1063
# Processing image 190/1063
# Processing image 191/1063
# Processing image 192/1063
# Processing image 193/1063
# Processing image 194/1063
# Processing image 195/1063
# Processing image 196/1063
# Processing image 197/1063
# Processing image 198/1063
# Processing image 199/1063
# Processing image 200/1063
# Processing image 201/1063
# Processing image 202/1063
# Processing image 203/1063
# Processing image 204/1063
# Processing image 205/1063
# Processing image 206/1063
# Processing image 207/1063
# Processing image 208/1063
# Processing image 209/1063
# Processing image 210/1063
# Processing image 211/1063
# Processing image 212/1063
# Processing image 213/1063
# Processing image 214/1063
# Processing image 215/1063
# Processing image 216/1063
# Processing image 217/1063
# Processing image 218/1063
# Processing image 219/1063
# Processing image 220/1063
# Processing image 221/1063
# Processing image 222/1063
# Processing image 223/1063
# Processing image 224/1063
# Processing image 225/1063
# Processing image 226/1063
# Processing image 227/1063
# Processing image 228/1063
# Processing image 229/1063
# Processing image 230/1063
# Processing image 231/1063
# Processing image 232/1063
# Processing image 233/1063
# Processing image 234/1063
# Processing image 235/1063
# Processing image 236/1063
# Processing image 237/1063
# Processing image 238/1063
# Processing image 239/1063
# Processing image 240/1063
# Processing image 241/1063
# Processing image 242/1063
# Processing image 243/1063
# Processing image 244/1063
# Processing image 245/1063
# Processing image 246/1063
# Processing image 247/1063
# Processing image 248/1063
# Processing image 249/1063
# Processing image 250/1063
# Processing image 251/1063
# Processing image 252/1063
# Processing image 253/1063
# Processing image 254/1063
# Processing image 255/1063
# Processing image 256/1063
# Processing image 257/1063
# Processing image 258/1063
# Processing image 259/1063
# Processing image 260/1063
# Processing image 261/1063
# Processing image 262/1063
# Processing image 263/1063
# Processing image 264/1063
# Processing image 265/1063
# Processing image 266/1063
# Processing image 267/1063
# Processing image 268/1063
# Processing image 269/1063
# Processing image 270/1063
# Processing image 271/1063
# Processing image 272/1063
# Processing image 273/1063
# Processing image 274/1063
# Processing image 275/1063
# Processing image 276/1063
# Processing image 277/1063
# Processing image 278/1063
# Processing image 279/1063
# Processing image 280/1063
# Processing image 281/1063
# Processing image 282/1063
# Processing image 283/1063
# Processing image 284/1063
# Processing image 285/1063
# Processing image 286/1063
# Processing image 287/1063
# Processing image 577/1063
# Processing image 578/1063
# Processing image 579/1063
# Processing image 580/1063
# Processing image 581/1063
# Processing image 582/1063
# Processing image 583/1063
# Processing image 584/1063
# Processing image 585/1063
# Processing image 586/1063
# Processing image 587/1063
# Processing image 588/1063
# Processing image 589/1063
# Processing image 590/1063
# Processing image 591/1063
# Processing image 592/1063
# Processing image 593/1063
# Processing image 594/1063
# Processing image 595/1063
# Processing image 596/1063
# Processing image 597/1063
# Processing image 598/1063
# Processing image 599/1063
# Processing image 600/1063
# Processing image 601/1063
# Processing image 602/1063
# Processing image 603/1063
# Processing image 604/1063
# Processing image 605/1063
# Processing image 606/1063
# Processing image 607/1063
# Processing image 608/1063
# Processing image 609/1063
# Processing image 610/1063
# Processing image 611/1063
# Processing image 612/1063
# Processing image 613/1063
# Processing image 614/1063
# Processing image 615/1063
# Processing image 616/1063
# Processing image 617/1063
# Processing image 618/1063
# Processing image 619/1063
# Processing image 620/1063
# Processing image 621/1063
# Processing image 622/1063
# Processing image 623/1063
# Processing image 624/1063
# Processing image 625/1063
# Processing image 626/1063
# Processing image 627/1063
# Processing image 628/1063
# Processing image 629/1063
# Processing image 630/1063
# Processing image 631/1063
# Processing image 632/1063
# Processing image 633/1063
# Processing image 634/1063
# Processing image 635/1063
# Processing image 636/1063
# Processing image 637/1063
# Processing image 638/1063
# Processing image 639/1063
# Processing image 640/1063
# Processing image 641/1063
# Processing image 642/1063
# Processing image 643/1063
# Processing image 644/1063
# Processing image 645/1063
# Processing image 646/1063
# Processing image 647/1063
# Processing image 648/1063
# Processing image 649/1063
# Processing image 650/1063
# Processing image 651/1063
# Processing image 652/1063
# Processing image 653/1063
# Processing image 654/1063
# Processing image 655/1063
# Processing image 656/1063
# Processing image 657/1063
# Processing image 658/1063
# Processing image 659/1063
# Processing image 660/1063
# Processing image 661/1063
# Processing image 662/1063
# Processing image 663/1063
# Processing image 664/1063
# Processing image 665/1063
# Processing image 666/1063
# Processing image 667/1063
# Processing image 668/1063
# Processing image 669/1063
# Processing image 670/1063
# Processing image 671/1063
# Processing image 672/1063
# Processing image 673/1063
# Processing image 674/1063
# Processing image 675/1063
# Processing image 676/1063
# Processing image 677/1063
# Processing image 678/1063
# Processing image 679/1063
# Processing image 680/1063
# Processing image 681/1063
# Processing image 682/1063
# Processing image 683/1063
# Processing image 684/1063
# Processing image 685/1063
# Processing image 686/1063
# Processing image 687/1063
# Processing image 688/1063
# Processing image 689/1063
# Processing image 690/1063
# Processing image 691/1063
# Processing image 692/1063
# Processing image 693/1063
# Processing image 694/1063
# Processing image 695/1063
# Processing image 696/1063
# Processing image 697/1063
# Processing image 698/1063
# Processing image 699/1063
# Processing image 700/1063
# Processing image 701/1063
# Processing image 702/1063
# Processing image 703/1063
# Processing image 704/1063
# Processing image 705/1063
# Processing image 706/1063
# Processing image 707/1063
# Processing image 708/1063
# Processing image 709/1063
# Processing image 710/1063
# Processing image 711/1063
# Processing image 712/1063
# Processing image 713/1063
# Processing image 714/1063
# Processing image 715/1063
# Processing image 716/1063
# Processing image 717/1063
# Processing image 718/1063
# Processing image 719/1063
# Processing image 720/1063
# Processing image 721/1063
# Processing image 722/1063
# Processing image 723/1063
# Processing image 724/1063
# Processing image 725/1063
# Processing image 726/1063
# Processing image 727/1063
# Processing image 728/1063
# Processing image 729/1063
# Processing image 730/1063
# Processing image 731/1063
# Processing image 732/1063
# Processing image 733/1063
# Processing image 734/1063
# Processing image 735/1063
# Processing image 736/1063
# Processing image 737/1063
# Processing image 738/1063
# Processing image 739/1063
# Processing image 740/1063
# Processing image 741/1063
# Processing image 742/1063
# Processing image 743/1063
# Processing image 744/1063
# Processing image 745/1063
# Processing image 746/1063
# Processing image 747/1063
# Processing image 748/1063
# Processing image 749/1063
# Processing image 750/1063
# Processing image 751/1063
# Processing image 752/1063
# Processing image 753/1063
# Processing image 754/1063
# Processing image 755/1063
# Processing image 756/1063
# Processing image 757/1063
# Processing image 758/1063
# Processing image 759/1063
# Processing image 760/1063
# Processing image 761/1063
# Processing image 762/1063
# Processing image 763/1063
# Processing image 764/1063
# Processing image 765/1063
# Processing image 766/1063
# Processing image 767/1063
# Processing image 768/1063
# Processing image 769/1063
# Processing image 770/1063
# Processing image 771/1063
# Processing image 772/1063
# Processing image 773/1063
# Processing image 774/1063
# Processing image 775/1063
# Processing image 776/1063
# Processing image 777/1063
# Processing image 778/1063
# Processing image 779/1063
# Processing image 780/1063
# Processing image 781/1063
# Processing image 782/1063
# Processing image 783/1063
# Processing image 784/1063
# Processing image 785/1063
# Processing image 786/1063
# Processing image 787/1063
# Processing image 788/1063
# Processing image 789/1063
# Processing image 790/1063
# Processing image 791/1063
# Processing image 792/1063
# Processing image 793/1063
# Processing image 794/1063
# Processing image 795/1063
# Processing image 796/1063
# Processing image 797/1063
# Processing image 798/1063
# Processing image 799/1063
# Processing image 800/1063
# Processing image 801/1063
# Processing image 802/1063
# Processing image 803/1063
# Processing image 804/1063
# Processing image 805/1063
# Processing image 806/1063
# Processing image 807/1063
# Processing image 808/1063
# Processing image 809/1063
# Processing image 810/1063
# Processing image 811/1063
# Processing image 812/1063
# Processing image 813/1063
# Processing image 814/1063
# Processing image 815/1063
# Processing image 816/1063
# Processing image 817/1063
# Processing image 818/1063
# Processing image 819/1063
# Processing image 820/1063
# Processing image 821/1063
# Processing image 822/1063
# Processing image 823/1063
# Processing image 824/1063
# Processing image 825/1063
# Processing image 826/1063
# Processing image 827/1063
# Processing image 828/1063
# Processing image 829/1063
# Processing image 830/1063
# Processing image 831/1063
# Processing image 832/1063
# Processing image 833/1063
# Processing image 834/1063
# Processing image 835/1063
# Processing image 836/1063
# Processing image 837/1063
# Processing image 838/1063
# Processing image 839/1063
# Processing image 840/1063
# Processing image 841/1063
# Processing image 842/1063
# Processing image 843/1063
# Processing image 844/1063
# Processing image 845/1063
# Processing image 846/1063
# Processing image 847/1063
# Processing image 848/1063
# Processing image 849/1063
# Processing image 850/1063
# Processing image 851/1063
# Processing image 852/1063
# Processing image 853/1063
# Processing image 854/1063
# Processing image 855/1063
# Processing image 856/1063
# Processing image 857/1063
# Processing image 858/1063
# Processing image 859/1063
# Processing image 860/1063
# Processing image 861/1063
# Processing image 862/1063
# Processing image 863/1063
# Processing image 864/1063
# Processing image 865/1063
# Processing image 866/1063
# Processing image 867/1063
# Processing image 868/1063
# Processing image 869/1063
# Processing image 870/1063
# Processing image 871/1063
# Processing image 872/1063
# Processing image 873/1063
# Processing image 874/1063
# Processing image 875/1063
# Processing image 876/1063
# Processing image 877/1063
# Processing image 878/1063
# Processing image 879/1063
# Processing image 880/1063
# Processing image 881/1063
# Processing image 882/1063
# Processing image 883/1063
# Processing image 884/1063
# Processing image 885/1063
# Processing image 886/1063
# Processing image 887/1063
# Processing image 888/1063
# Processing image 889/1063
# Processing image 890/1063
# Processing image 891/1063
# Processing image 892/1063
# Processing image 893/1063
# Processing image 894/1063
# Processing image 895/1063
# Processing image 896/1063
# Processing image 897/1063
# Processing image 898/1063
# Processing image 899/1063
# Processing image 900/1063
# Processing image 901/1063
# Processing image 902/1063
# Processing image 903/1063
# Processing image 904/1063
# Processing image 905/1063
# Processing image 906/1063
# Processing image 907/1063
# Processing image 908/1063
# Processing image 909/1063
# Processing image 910/1063
# Processing image 911/1063
# Processing image 912/1063
# Processing image 913/1063
# Processing image 914/1063
# Processing image 915/1063
# Processing image 916/1063
# Processing image 917/1063
# Processing image 918/1063
# Processing image 919/1063
# Processing image 920/1063
# Processing image 921/1063
# Processing image 922/1063
# Processing image 923/1063
# Processing image 924/1063
# Processing image 925/1063
# Processing image 926/1063
# Processing image 927/1063
# Processing image 928/1063
# Processing image 929/1063
# Processing image 930/1063
# Processing image 931/1063
# Processing image 932/1063
# Processing image 933/1063
# Processing image 934/1063
# Processing image 935/1063
# Processing image 936/1063
# Processing image 937/1063
# Processing image 938/1063
# Processing image 939/1063
# Processing image 940/1063
# Processing image 941/1063
# Processing image 942/1063
# Processing image 943/1063
# Processing image 944/1063
# Processing image 945/1063
# Processing image 946/1063
# Processing image 947/1063
# Processing image 948/1063
# Processing image 949/1063
# Processing image 950/1063
# Processing image 951/1063
# Processing image 952/1063
# Processing image 953/1063
# Processing image 954/1063
# Processing image 955/1063
# Processing image 956/1063
# Processing image 957/1063
# Processing image 958/1063
# Processing image 959/1063
# Processing image 960/1063
# Processing image 961/1063
# Processing image 962/1063
# Processing image 963/1063
# Processing image 964/1063
# Processing image 965/1063
# Processing image 966/1063
# Processing image 967/1063
# Processing image 968/1063
# Processing image 969/1063
# Processing image 970/1063
# Processing image 971/1063
# Processing image 972/1063
# Processing image 973/1063
# Processing image 974/1063
# Processing image 975/1063
# Processing image 976/1063
# Processing image 977/1063
# Processing image 978/1063
# Processing image 979/1063
# Processing image 980/1063
# Processing image 981/1063
# Processing image 982/1063
# Processing image 983/1063
# Processing image 984/1063
# Processing image 985/1063
# Processing image 986/1063
# Processing image 987/1063
# Processing image 988/1063
# Processing image 989/1063
# Processing image 990/1063
# Processing image 991/1063
# Processing image 992/1063
# Processing image 993/1063
# Processing image 994/1063
# Processing image 995/1063
# Processing image 996/1063
# Processing image 997/1063
# Processing image 998/1063
# Processing image 999/1063
# Processing image 1000/1063
# Processing image 1001/1063
# Processing image 1002/1063
# Processing image 1003/1063
# Processing image 1004/1063
# Processing image 1005/1063
# Processing image 1006/1063
# Processing image 1007/1063
# Processing image 1008/1063
# Processing image 1009/1063
# Processing image 1010/1063
# Processing image 1011/1063
# Processing image 1012/1063
# Processing image 1013/1063
# Processing image 1014/1063
# Processing image 1015/1063
# Processing image 1016/1063
# Processing image 1017/1063
# Processing image 1018/1063
# Processing image 1019/1063
# Processing image 1020/1063
# Processing image 1021/1063
# Processing image 1022/1063
# Processing image 1023/1063
# Processing image 1024/1063
# Processing image 1025/1063
# Processing image 1026/1063
# Processing image 1027/1063
# Processing image 1028/1063
# Processing image 1029/1063
# Processing image 1030/1063
# Processing image 1031/1063
# Processing image 1032/1063
# Processing image 1033/1063
# Processing image 1034/1063
# Processing image 1035/1063
# Processing image 1036/1063
# Processing image 1037/1063
# Processing image 1038/1063
# Processing image 1039/1063
# Processing image 1040/1063
# Processing image 1041/1063
# Processing image 1042/1063
# Processing image 1043/1063
# Processing image 1044/1063
# Processing image 1045/1063
# Processing image 1046/1063
# Processing image 1047/1063
# Processing image 1048/1063
# Processing image 1049/1063
# Processing image 1050/1063
# Processing image 1051/1063
# Processing image 1052/1063
# Processing image 1053/1063
# Processing image 1054/1063
# Processing image 1055/1063
# Processing image 1056/1063
# Processing image 1057/1063
# Processing image 1058/1063
# Processing image 1059/1063
# Processing image 1060/1063
# Processing image 1061/1063
# Processing image 1062/1063
# Processing image 1063/1063

# %%
# Save (pickle) the embeddings and the names

print('Serializing {} encodings:\n'.format(total))

data = {'embeddings': knownEmbeddings, 'names': knownNames}                       # Saved as a dictionary/ HashMap
f = open(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\New TF Model Test\Output Embeddings\embeddings.pickle', 'wb')
f.write(pickle.dumps(data))                                                       # Stored as a ByteStream
f.close()
print("Serialized {} encodings.\n".format(total))
# Out:
# Serializing 1031 encodings:
#
# Serialized 1031 encodings.

# %% [markdown]
# # **Train the face recognition model**

# %%
pip install -U scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'c:\users\yash' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
import argparse
import pickle

# %%
print("Loading face embeddings:\n")
data = pickle.loads(open(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\New TF Model Test\Output Embeddings\embeddings.pickle', 'rb').read())
print("Loaded.\n\n")

print("Encoding labels:\n")
le = LabelEncoder()
labels = le.fit_transform(data['names'])
print("\nLabels encoded.\n")
# Out:
# Loading face embeddings:
#
# Loaded.
#
#
# Encoding labels:
#
#
# Labels encoded.

# %%
print("Training model...\n")
recognizer = SVC(C = 1.0, kernel = "linear", probability = True)
recognizer.fit(data["embeddings"], labels)
print("\nModel trained.\n")
# Out:
# Training model...
#
#
# Model trained.

# %%
# Save the actual face recognition model
f = open(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\New TF Model Test\Trained Models\recognizer.pickle', "wb")
f.write(pickle.dumps(recognizer))
f.close()

# Save the label encoder
f = open(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\New TF Model Test\Trained Models\le.pickle', "wb")
f.write(pickle.dumps(le))
f.close()

# %% [markdown]
# # **Recognise faces using OpenCV**

# %%
from imutils.video import VideoStream
from imutils.video import FPS
import numpy as np
import argparse
import imutils
import pickle
import time
import cv2
import os
from keras.models import model_from_json
from tf_models.inception_resnet_v1 import *
import json
from keras.preprocessing.image import load_img, save_img, img_to_array
from keras.applications.imagenet_utils import preprocess_input

# %%
# Load our serialized face detector

print("Loading face detector...\n")
protoPath = os.path.sep.join([r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\opencv-face-recognition\face_detection_model', 'deploy.prototxt'])
modelPath = os.path.sep.join([r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\opencv-face-recognition\face_detection_model', 'res10_300x300_ssd_iter_140000.caffemodel'])
detector = cv2.dnn.readNetFromCaffe(protoPath, modelPath)
print("Loaded face detector.\n")

# Load our serialized face embedding model
print("\nLoading face recognizer...\n")
embedder = InceptionResNetV1()
embedder.load_weights('facenet_weights.h5')
# embedder = cv2.dnn.readNetFromTensorflow(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\New TF Model Test\Model\tf-model.pb')
print("Loaded Face Recognizer.\n")

# Load the SVM Model and LabelEncoder
recognizer = pickle.loads(open(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\New TF Model Test\Trained Models\recognizer.pickle', "rb").read())
le = pickle.loads(open(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\New TF Model Test\Trained Models\le.pickle', "rb").read())
# Out:
# Loading face detector...
#
# Loaded face detector.
#
#
# Loading face recognizer...
#
# Loaded Face Recognizer.

# %%
# Initialize the video stream, then allow the camera sensor to warm up

print("Starting video stream...\n")

vs = VideoStream(src = 0).start()
time.sleep(2.0)

# Start FPS Throughput Estimator
fps = FPS().start()

# Loop over frames
while True:
  frame = vs.read()
  frame = imutils.resize(frame, width = 600)
  (h, w) = frame.shape[:2]

  imageBlob = cv2.dnn.blobFromImage(cv2.resize(frame, (300, 300)), 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB = False, crop = False)

  detector.setInput(imageBlob)
  detections = detector.forward()

  for i in range(0, detections.shape[2]):
    confidence = detections[0, 0, i, 2]

    if (confidence > 0.7):
      box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
      (startX, startY, endX, endY) = box.astype("int")

      face = frame[startY: endY, startX: endX]
      (fH, fW) = face.shape[:2]

      if ((fW < 20) or (fH < 20)):
        continue
      
      # faceBlob = cv2.dnn.blobFromImage(face, 1.0/255, (96, 96), (0, 0, 0), swapRB = True, crop = False)

      # embedder.setInput(faceBlob)
      vec = embedder.predict(preprocess_image_img(face))[0, :].reshape(1, -1)
      # print(vec)

      preds = recognizer.predict_proba(vec)[0]
      # print(preds)
      j = np.argmax(preds)
      proba = preds[j]
      name = le.classes_[j]

      text = "{}: {:.2f}%".format(name, proba * 100)
      y = startY - 10 if (startY - 10 > 10) else (startY + 10)

      cv2.rectangle(frame, (startX, startY), (endX, endY), (0, 0, 255), 2)
      cv2.putText(frame, text, (startX, y), cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 0, 255), 2)
  
  fps.update()
  cv2.imshow("Frame", frame)

  key = cv2.waitKey(1) & 0xFF
  if (key == ord('q') or key == ord('Q')):
    break
  
fps.stop()

print("Elapsed time: {:.2f}".format(fps.elapsed()))
print("Approx. FPS: {:.2f}".format(fps.fps()))

cv2.destroyAllWindows()
vs.stop()
# Out:
# Starting video stream...
#
# Elapsed time: 43.94
# Approx. FPS: 6.96

# %%
import tensorflow
print(tensorflow.version)
# Out:
# <module 'tensorflow._api.v2.version' from 'C:\\Users\\Yash Umale\\AppData\\Roaming\\Python\\Python39\\site-packages\\tensorflow\\_api\\v2\\version\\__init__.py'>

# %%
import tensorflow as tf

# Convert the model
converter = tf.lite.TFLiteConverter.from_saved_model(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\tf_models\facenet_embedder') # path to the SavedModel directory
tflite_model = converter.convert()

# Save the model.
with open('saved_model.tflite', 'wb') as f:
  f.write(tflite_model)
