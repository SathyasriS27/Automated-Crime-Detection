# %%
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        # !pip install --upgrade imutils
# Out:
# Requirement already up-to-date: imutils in c:\users\yash umale\appdata\local\programs\python\python39\lib\site-packages (0.5.4)
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\users\yash umale\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in c:\users\yash umale\appdata\local\programs\python\python39\lib\site-packages (4.5.1.48)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\yash umale\appdata\local\programs\python\python39\lib\site-packages (from opencv-contrib-python) (1.20.1)
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\users\yash umale\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# # **Extract embeddings from face dataset**

# %%
# Importing all necessary packages

from imutils import paths
import numpy as np
import argparse
import imutils
import pickle
import time
import cv2
import os
from keras.models import model_from_json
from tf_models.inception_resnet_v1 import *
import json
from keras.preprocessing.image import load_img, save_img, img_to_array
from keras.applications.imagenet_utils import preprocess_input

# %%
# Load face detector
from tf_models.inception_resnet_v1 import *

print("Loading face detector...")

protoPath = os.path.sep.join([r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\opencv-face-recognition\face_detection_model', 'deploy.prototxt'])
modelPath = os.path.sep.join([r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\opencv-face-recognition\face_detection_model', 'res10_300x300_ssd_iter_140000.caffemodel'])

detector = cv2.dnn.readNetFromCaffe(protoPath, modelPath)


# Load face recognizer

print("\nLoading face recognizer...")
embedder = InceptionResNetV1()
# embedder = cv2.dnn.readNetFromTorch(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\opencv-face-recognition\openface_nn4.small2.v1.t7')

def preprocess_image(image_path):
    img = load_img(image_path, target_size=(160, 160))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = preprocess_input(img)
    return img

def preprocess_image_img(img):
    img = cv2.resize(img, (160, 160))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = preprocess_input(img)
    return img
# Out:
# Loading face detector...
#
# Loading face recognizer...

# %%
# Entering paths to our images dataset

print('\nQuantifying faces...')
imagePaths = list(paths.list_images(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\Datasets'))

knownEmbeddings = []
knownNames = []

# Total number of faces
total = 0
# Out:
# Quantifying faces...

# %%
# Loop over all image paths

for (i, imagePath) in enumerate(imagePaths):
  print("Processing image {}/{}".format(i + 1, len(imagePaths)))                  # Extract the person name from the image path
  name = imagePath.split(os.path.sep)[-2]

  image = cv2.imread(imagePath)                                                   # Load the image
  image = imutils.resize(image, width=600)                                        # Resize to (600, 600)
  (h, w) = image.shape[:2]                                                        # Store image dimensions
  imageBlob = cv2.dnn.blobFromImage(                                              # Construct a blob from the image
  	cv2.resize(image, (300, 300)), 1.0, (300, 300),
  	(104.0, 177.0, 123.0), swapRB=False, crop=False)

  detector.setInput(imageBlob)                                                    # Face Detector to localize face in an image
  detections = detector.forward()       

  if len(detections) > 0:                                                         # Ensure at least one face was found
    i = np.argmax(detections[0, 0, :, 2])
    confidence = detections[0, 0, i, 2]        

    if (confidence > 0.1):                                                          # Filtering weak detections
      box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
      (startX, startY, endX, endY) = box.astype("int")
			
      face = image[startY:endY, startX:endX]
      (fH, fW) = face.shape[:2]
			
      if (fW < 20 or fH < 20):
        continue    

      
      # faceBlob = cv2.dnn.blobFromImage(face, 1.0 / 255, (160, 160), (0, 0, 0), 
      #                                  swapRB=True, crop=False)                   # Create blob

      # embedder.setInput(faceBlob)
      vec = embedder.predict(preprocess_image_img(face))[0, :].reshape(1, -1)

      knownNames.append(name)                                                     # Append name to list
      knownEmbeddings.append(vec.flatten())                                       # Append flattened embedding to list
      total += 1
# Out:
# Processing image 1/679
# Processing image 2/679
# Processing image 3/679
# Processing image 4/679
# Processing image 5/679
# Processing image 6/679
# Processing image 7/679
# Processing image 8/679
# Processing image 9/679
# Processing image 10/679
# Processing image 11/679
# Processing image 12/679
# Processing image 13/679
# Processing image 14/679
# Processing image 15/679
# Processing image 16/679
# Processing image 17/679
# Processing image 18/679
# Processing image 19/679
# Processing image 20/679
# Processing image 21/679
# Processing image 22/679
# Processing image 23/679
# Processing image 24/679
# Processing image 25/679
# Processing image 26/679
# Processing image 27/679
# Processing image 28/679
# Processing image 29/679
# Processing image 30/679
# Processing image 31/679
# Processing image 32/679
# Processing image 33/679
# Processing image 34/679
# Processing image 35/679
# Processing image 36/679
# Processing image 37/679
# Processing image 38/679
# Processing image 39/679
# Processing image 40/679
# Processing image 41/679
# Processing image 42/679
# Processing image 43/679
# Processing image 44/679
# Processing image 45/679
# Processing image 46/679
# Processing image 47/679
# Processing image 48/679
# Processing image 49/679
# Processing image 50/679
# Processing image 51/679
# Processing image 52/679
# Processing image 53/679
# Processing image 54/679
# Processing image 55/679
# Processing image 56/679
# Processing image 57/679
# Processing image 58/679
# Processing image 59/679
# Processing image 60/679
# Processing image 61/679
# Processing image 62/679
# Processing image 63/679
# Processing image 64/679
# Processing image 65/679
# Processing image 66/679
# Processing image 67/679
# Processing image 68/679
# Processing image 69/679
# Processing image 70/679
# Processing image 71/679
# Processing image 72/679
# Processing image 73/679
# Processing image 74/679
# Processing image 75/679
# Processing image 76/679
# Processing image 77/679
# Processing image 78/679
# Processing image 79/679
# Processing image 80/679
# Processing image 81/679
# Processing image 82/679
# Processing image 83/679
# Processing image 84/679
# Processing image 85/679
# Processing image 86/679
# Processing image 87/679
# Processing image 88/679
# Processing image 89/679
# Processing image 90/679
# Processing image 91/679
# Processing image 92/679
# Processing image 93/679
# Processing image 94/679
# Processing image 95/679
# Processing image 96/679
# Processing image 97/679
# Processing image 98/679
# Processing image 99/679
# Processing image 100/679
# Processing image 101/679
# Processing image 102/679
# Processing image 103/679
# Processing image 104/679
# Processing image 105/679
# Processing image 106/679
# Processing image 107/679
# Processing image 108/679
# Processing image 109/679
# Processing image 110/679
# Processing image 111/679
# Processing image 112/679
# Processing image 113/679
# Processing image 114/679
# Processing image 115/679
# Processing image 116/679
# Processing image 117/679
# Processing image 118/679
# Processing image 119/679
# Processing image 120/679
# Processing image 121/679
# Processing image 122/679
# Processing image 123/679
# Processing image 124/679
# Processing image 125/679
# Processing image 126/679
# Processing image 127/679
# Processing image 128/679
# Processing image 129/679
# Processing image 130/679
# Processing image 131/679
# Processing image 132/679
# Processing image 133/679
# Processing image 134/679
# Processing image 135/679
# Processing image 136/679
# Processing image 137/679
# Processing image 138/679
# Processing image 139/679
# Processing image 140/679
# Processing image 141/679
# Processing image 142/679
# Processing image 143/679
# Processing image 144/679
# Processing image 145/679
# Processing image 146/679
# Processing image 147/679
# Processing image 148/679
# Processing image 149/679
# Processing image 150/679
# Processing image 151/679
# Processing image 152/679
# Processing image 153/679
# Processing image 154/679
# Processing image 155/679
# Processing image 156/679
# Processing image 157/679
# Processing image 158/679
# Processing image 159/679
# Processing image 160/679
# Processing image 161/679
# Processing image 162/679
# Processing image 163/679
# Processing image 164/679
# Processing image 165/679
# Processing image 166/679
# Processing image 167/679
# Processing image 168/679
# Processing image 169/679
# Processing image 170/679
# Processing image 171/679
# Processing image 172/679
# Processing image 173/679
# Processing image 174/679
# Processing image 175/679
# Processing image 176/679
# Processing image 177/679
# Processing image 178/679
# Processing image 179/679
# Processing image 180/679
# Processing image 181/679
# Processing image 182/679
# Processing image 183/679
# Processing image 184/679
# Processing image 185/679
# Processing image 186/679
# Processing image 187/679
# Processing image 188/679
# Processing image 189/679
# Processing image 190/679
# Processing image 191/679
# Processing image 192/679
# Processing image 193/679
# Processing image 194/679
# Processing image 195/679
# Processing image 196/679
# Processing image 197/679
# Processing image 198/679
# Processing image 199/679
# Processing image 200/679
# Processing image 201/679
# Processing image 202/679
# Processing image 203/679
# Processing image 204/679
# Processing image 205/679
# Processing image 206/679
# Processing image 207/679
# Processing image 208/679
# Processing image 209/679
# Processing image 210/679
# Processing image 211/679
# Processing image 212/679
# Processing image 213/679
# Processing image 214/679
# Processing image 215/679
# Processing image 216/679
# Processing image 217/679
# Processing image 218/679
# Processing image 219/679
# Processing image 220/679
# Processing image 221/679
# Processing image 222/679
# Processing image 223/679
# Processing image 224/679
# Processing image 225/679
# Processing image 226/679
# Processing image 227/679
# Processing image 228/679
# Processing image 229/679
# Processing image 230/679
# Processing image 231/679
# Processing image 232/679
# Processing image 233/679
# Processing image 234/679
# Processing image 235/679
# Processing image 236/679
# Processing image 237/679
# Processing image 238/679
# Processing image 239/679
# Processing image 240/679
# Processing image 241/679
# Processing image 242/679
# Processing image 243/679
# Processing image 244/679
# Processing image 245/679
# Processing image 246/679
# Processing image 247/679
# Processing image 248/679
# Processing image 249/679
# Processing image 250/679
# Processing image 251/679
# Processing image 252/679
# Processing image 253/679
# Processing image 254/679
# Processing image 255/679
# Processing image 256/679
# Processing image 257/679
# Processing image 258/679
# Processing image 259/679
# Processing image 260/679
# Processing image 261/679
# Processing image 262/679
# Processing image 263/679
# Processing image 264/679
# Processing image 265/679
# Processing image 266/679
# Processing image 267/679
# Processing image 268/679
# Processing image 269/679
# Processing image 270/679
# Processing image 271/679
# Processing image 272/679
# Processing image 273/679
# Processing image 274/679
# Processing image 275/679
# Processing image 276/679
# Processing image 277/679
# Processing image 278/679
# Processing image 279/679
# Processing image 280/679
# Processing image 281/679
# Processing image 282/679
# Processing image 283/679
# Processing image 284/679
# Processing image 285/679
# Processing image 286/679
# Processing image 287/679
# Processing image 288/679
# Processing image 289/679
# Processing image 290/679
# Processing image 291/679
# Processing image 292/679
# Processing image 293/679
# Processing image 294/679
# Processing image 295/679
# Processing image 296/679
# Processing image 297/679
# Processing image 298/679
# Processing image 299/679
# Processing image 300/679
# Processing image 301/679
# Processing image 302/679
# Processing image 303/679
# Processing image 304/679
# Processing image 305/679
# Processing image 306/679
# Processing image 307/679
# Processing image 308/679
# Processing image 309/679
# Processing image 310/679
# Processing image 311/679
# Processing image 312/679
# Processing image 313/679
# Processing image 314/679
# Processing image 315/679
# Processing image 316/679
# Processing image 317/679
# Processing image 318/679
# Processing image 319/679
# Processing image 320/679
# Processing image 321/679
# Processing image 322/679
# Processing image 323/679
# Processing image 324/679
# Processing image 325/679
# Processing image 326/679
# Processing image 327/679
# Processing image 328/679
# Processing image 329/679
# Processing image 330/679
# Processing image 331/679
# Processing image 332/679
# Processing image 333/679
# Processing image 334/679
# Processing image 335/679
# Processing image 336/679
# Processing image 337/679
# Processing image 338/679
# Processing image 339/679
# Processing image 340/679
# Processing image 341/679
# Processing image 342/679
# Processing image 343/679
# Processing image 344/679
# Processing image 345/679
# Processing image 346/679
# Processing image 347/679
# Processing image 348/679
# Processing image 349/679
# Processing image 350/679
# Processing image 351/679
# Processing image 352/679
# Processing image 353/679
# Processing image 354/679
# Processing image 355/679
# Processing image 356/679
# Processing image 357/679
# Processing image 358/679
# Processing image 359/679
# Processing image 360/679
# Processing image 361/679
# Processing image 362/679
# Processing image 363/679
# Processing image 364/679
# Processing image 365/679
# Processing image 366/679
# Processing image 367/679
# Processing image 368/679
# Processing image 369/679
# Processing image 370/679
# Processing image 371/679
# Processing image 372/679
# Processing image 373/679
# Processing image 374/679
# Processing image 375/679
# Processing image 376/679
# Processing image 377/679
# Processing image 378/679
# Processing image 379/679
# Processing image 380/679
# Processing image 381/679
# Processing image 382/679
# Processing image 383/679
# Processing image 384/679
# Processing image 385/679
# Processing image 386/679
# Processing image 387/679
# Processing image 388/679
# Processing image 389/679
# Processing image 390/679
# Processing image 391/679
# Processing image 392/679
# Processing image 393/679
# Processing image 394/679
# Processing image 395/679
# Processing image 396/679
# Processing image 397/679
# Processing image 398/679
# Processing image 399/679
# Processing image 400/679
# Processing image 401/679
# Processing image 402/679
# Processing image 403/679
# Processing image 404/679
# Processing image 405/679
# Processing image 406/679
# Processing image 407/679
# Processing image 408/679
# Processing image 409/679
# Processing image 410/679
# Processing image 411/679
# Processing image 412/679
# Processing image 413/679
# Processing image 414/679
# Processing image 415/679
# Processing image 416/679
# Processing image 417/679
# Processing image 418/679
# Processing image 419/679
# Processing image 420/679
# Processing image 421/679
# Processing image 422/679
# Processing image 423/679
# Processing image 424/679
# Processing image 425/679
# Processing image 426/679
# Processing image 427/679
# Processing image 428/679
# Processing image 429/679
# Processing image 430/679
# Processing image 431/679
# Processing image 432/679
# Processing image 433/679
# Processing image 434/679
# Processing image 435/679
# Processing image 436/679
# Processing image 437/679
# Processing image 438/679
# Processing image 439/679
# Processing image 440/679
# Processing image 441/679
# Processing image 442/679
# Processing image 443/679
# Processing image 444/679
# Processing image 445/679
# Processing image 446/679
# Processing image 447/679
# Processing image 448/679
# Processing image 449/679
# Processing image 450/679
# Processing image 451/679
# Processing image 452/679
# Processing image 453/679
# Processing image 454/679
# Processing image 455/679
# Processing image 456/679
# Processing image 457/679
# Processing image 458/679
# Processing image 459/679
# Processing image 460/679
# Processing image 461/679
# Processing image 462/679
# Processing image 463/679
# Processing image 464/679
# Processing image 465/679
# Processing image 466/679
# Processing image 467/679
# Processing image 468/679
# Processing image 469/679
# Processing image 470/679
# Processing image 471/679
# Processing image 472/679
# Processing image 473/679
# Processing image 474/679
# Processing image 475/679
# Processing image 476/679
# Processing image 477/679
# Processing image 478/679
# Processing image 479/679
# Processing image 480/679
# Processing image 481/679
# Processing image 482/679
# Processing image 483/679
# Processing image 484/679
# Processing image 485/679
# Processing image 486/679
# Processing image 487/679
# Processing image 488/679
# Processing image 489/679
# Processing image 490/679
# Processing image 491/679
# Processing image 492/679
# Processing image 493/679
# Processing image 494/679
# Processing image 495/679
# Processing image 496/679
# Processing image 497/679
# Processing image 498/679
# Processing image 499/679
# Processing image 500/679
# Processing image 501/679
# Processing image 502/679
# Processing image 503/679
# Processing image 504/679
# Processing image 505/679
# Processing image 506/679
# Processing image 507/679
# Processing image 508/679
# Processing image 509/679
# Processing image 510/679
# Processing image 511/679
# Processing image 512/679
# Processing image 513/679
# Processing image 514/679
# Processing image 515/679
# Processing image 516/679
# Processing image 517/679
# Processing image 518/679
# Processing image 519/679
# Processing image 520/679
# Processing image 521/679
# Processing image 522/679
# Processing image 523/679
# Processing image 524/679
# Processing image 525/679
# Processing image 526/679
# Processing image 527/679
# Processing image 528/679
# Processing image 529/679
# Processing image 530/679
# Processing image 531/679
# Processing image 532/679
# Processing image 533/679
# Processing image 534/679
# Processing image 535/679
# Processing image 536/679
# Processing image 537/679
# Processing image 538/679
# Processing image 539/679
# Processing image 540/679
# Processing image 541/679
# Processing image 542/679
# Processing image 543/679
# Processing image 544/679
# Processing image 545/679
# Processing image 546/679
# Processing image 547/679
# Processing image 548/679
# Processing image 549/679
# Processing image 550/679
# Processing image 551/679
# Processing image 552/679
# Processing image 553/679
# Processing image 554/679
# Processing image 555/679
# Processing image 556/679
# Processing image 557/679
# Processing image 558/679
# Processing image 559/679
# Processing image 560/679
# Processing image 561/679
# Processing image 562/679
# Processing image 563/679
# Processing image 564/679
# Processing image 565/679
# Processing image 566/679
# Processing image 567/679
# Processing image 568/679
# Processing image 569/679
# Processing image 570/679
# Processing image 571/679
# Processing image 572/679
# Processing image 573/679
# Processing image 574/679
# Processing image 575/679
# Processing image 576/679
# Processing image 577/679
# Processing image 578/679
# Processing image 579/679
# Processing image 580/679
# Processing image 581/679
# Processing image 582/679
# Processing image 583/679
# Processing image 584/679
# Processing image 585/679
# Processing image 586/679
# Processing image 587/679
# Processing image 588/679
# Processing image 589/679
# Processing image 590/679
# Processing image 591/679
# Processing image 592/679
# Processing image 593/679
# Processing image 594/679
# Processing image 595/679
# Processing image 596/679
# Processing image 597/679
# Processing image 598/679
# Processing image 599/679
# Processing image 600/679
# Processing image 601/679
# Processing image 602/679
# Processing image 603/679
# Processing image 604/679
# Processing image 605/679
# Processing image 606/679
# Processing image 607/679
# Processing image 608/679
# Processing image 609/679
# Processing image 610/679
# Processing image 611/679
# Processing image 612/679
# Processing image 613/679
# Processing image 614/679
# Processing image 615/679
# Processing image 616/679
# Processing image 617/679
# Processing image 618/679
# Processing image 619/679
# Processing image 620/679
# Processing image 621/679
# Processing image 622/679
# Processing image 623/679
# Processing image 624/679
# Processing image 625/679
# Processing image 626/679
# Processing image 627/679
# Processing image 628/679
# Processing image 629/679
# Processing image 630/679
# Processing image 631/679
# Processing image 632/679
# Processing image 633/679
# Processing image 634/679
# Processing image 635/679
# Processing image 636/679
# Processing image 637/679
# Processing image 638/679
# Processing image 639/679
# Processing image 640/679
# Processing image 641/679
# Processing image 642/679
# Processing image 643/679
# Processing image 644/679
# Processing image 645/679
# Processing image 646/679
# Processing image 647/679
# Processing image 648/679
# Processing image 649/679
# Processing image 650/679
# Processing image 651/679
# Processing image 652/679
# Processing image 653/679
# Processing image 654/679
# Processing image 655/679
# Processing image 656/679
# Processing image 657/679
# Processing image 658/679
# Processing image 659/679
# Processing image 660/679
# Processing image 661/679
# Processing image 662/679
# Processing image 663/679
# Processing image 664/679
# Processing image 665/679
# Processing image 666/679
# Processing image 667/679
# Processing image 668/679
# Processing image 669/679
# Processing image 670/679
# Processing image 671/679
# Processing image 672/679
# Processing image 673/679
# Processing image 674/679
# Processing image 675/679
# Processing image 676/679
# Processing image 677/679
# Processing image 678/679
# Processing image 679/679

# %%
# Save (pickle) the embeddings and the names

print('Serializing {} encodings:\n'.format(total))

data = {'embeddings': knownEmbeddings, 'names': knownNames}                       # Saved as a dictionary/ HashMap
f = open(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\New TF Model Test\Output Embeddings\embeddings.pickle', 'wb')
f.write(pickle.dumps(data))                                                       # Stored as a ByteStream
f.close()
print("Serialized {} encodings.\n".format(total))
# Out:
# Serializing 663 encodings:
#
# Serialized 663 encodings.

# %% [markdown]
# # **Train the face recognition model**

# %%
pip install -U scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'c:\users\yash' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
import argparse
import pickle

# %%
print("Loading face embeddings:\n")
data = pickle.loads(open(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\New TF Model Test\Output Embeddings\embeddings.pickle', 'rb').read())
print("Loaded.\n\n")

print("Encoding labels:\n")
le = LabelEncoder()
labels = le.fit_transform(data['names'])
print("\nLabels encoded.\n")
# Out:
# Loading face embeddings:
#
# Loaded.
#
#
# Encoding labels:
#
#
# Labels encoded.

# %%
print("Training model...\n")
recognizer = SVC(C = 1.0, kernel = "linear", probability = True)
recognizer.fit(data["embeddings"], labels)
print("\nModel trained.\n")
# Out:
# Training model...
#
#
# Model trained.

# %%
# Save the actual face recognition model
f = open(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\New TF Model Test\Trained Models\recognizer.pickle', "wb")
f.write(pickle.dumps(recognizer))
f.close()

# Save the label encoder
f = open(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\New TF Model Test\Trained Models\le.pickle', "wb")
f.write(pickle.dumps(le))
f.close()

# %% [markdown]
# # **Recognise faces using OpenCV**

# %%
from imutils.video import VideoStream
from imutils.video import FPS
import numpy as np
import argparse
import imutils
import pickle
import time
import cv2
import os
from keras.models import model_from_json
from tf_models.inception_resnet_v1 import *
import json
from keras.preprocessing.image import load_img, save_img, img_to_array
from keras.applications.imagenet_utils import preprocess_input

# %%
# Load our serialized face detector

print("Loading face detector...\n")
protoPath = os.path.sep.join([r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\opencv-face-recognition\face_detection_model', 'deploy.prototxt'])
modelPath = os.path.sep.join([r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\opencv-face-recognition\face_detection_model', 'res10_300x300_ssd_iter_140000.caffemodel'])
detector = cv2.dnn.readNetFromCaffe(protoPath, modelPath)
print("Loaded face detector.\n")

# Load our serialized face embedding model
print("\nLoading face recognizer...\n")
embedder = InceptionResNetV1()
# embedder = cv2.dnn.readNetFromTensorflow(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\New TF Model Test\Model\tf-model.pb')
print("Loaded Face Recognizer.\n")

# Load the SVM Model and LabelEncoder
recognizer = pickle.loads(open(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\New TF Model Test\Trained Models\recognizer.pickle', "rb").read())
le = pickle.loads(open(r'C:\Users\Yash Umale\Documents\6th Sem\Open Lab\Python Files\Project Files\New TF Model Test\Trained Models\le.pickle', "rb").read())
# Out:
# Loading face detector...
#
# Loaded face detector.
#
#
# Loading face recognizer...
#
# Loaded Face Recognizer.

# %%
# Initialize the video stream, then allow the camera sensor to warm up

print("Starting video stream...\n")

vs = VideoStream(src = 0).start()
time.sleep(2.0)

# Start FPS Throughput Estimator
fps = FPS().start()

# Loop over frames
while True:
  frame = vs.read()
  frame = imutils.resize(frame, width = 600)
  (h, w) = frame.shape[:2]

  imageBlob = cv2.dnn.blobFromImage(cv2.resize(frame, (300, 300)), 1.0, (300, 300), (104.0, 177.0, 123.0), swapRB = False, crop = False)

  detector.setInput(imageBlob)
  detections = detector.forward()

  for i in range(0, detections.shape[2]):
    confidence = detections[0, 0, i, 2]

    if (confidence > 0.2):
      box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
      (startX, startY, endX, endY) = box.astype("int")

      face = frame[startY: endY, startX: endX]
      (fH, fW) = face.shape[:2]

      if ((fW < 20) or (fH < 20)):
        continue
      
      # faceBlob = cv2.dnn.blobFromImage(face, 1.0/255, (96, 96), (0, 0, 0), swapRB = True, crop = False)

      # embedder.setInput(faceBlob)
      vec = embedder.predict(preprocess_image_img(face))[0, :].reshape(1, -1)
      # print(vec)

      preds = recognizer.predict_proba(vec)[0]
      # print(preds)
      j = np.argmax(preds)
      proba = preds[j]
      name = le.classes_[j]

      text = "{}: {:.2f}%".format(name, proba * 100)
      y = startY - 10 if (startY - 10 > 10) else (startY + 10)

      cv2.rectangle(frame, (startX, startY), (endX, endY), (0, 0, 255), 2)
      cv2.putText(frame, text, (startX, y), cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 0, 255), 2)
  
  fps.update()
  cv2.imshow("Frame", frame)

  key = cv2.waitKey(1) & 0xFF
  if (key == ord('q') or key == ord('Q')):
    break
  
fps.stop()

print("Elapsed time: {:.2f}".format(fps.elapsed()))
print("Approx. FPS: {:.2f}".format(fps.fps()))

cv2.destroyAllWindows()
vs.stop()
# Out:
# Starting video stream...
#
# Elapsed time: 149.35
# Approx. FPS: 7.79

# %%
import tensorflow
print(tensorflow.version)
# Out:
# <module 'tensorflow._api.v2.version' from 'C:\\Users\\Yash Umale\\AppData\\Roaming\\Python\\Python39\\site-packages\\tensorflow\\_api\\v2\\version\\__init__.py'>
