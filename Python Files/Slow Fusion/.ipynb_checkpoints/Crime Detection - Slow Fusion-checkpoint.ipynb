# %%
# set the matplotlib backend so figures can be saved in the background
import matplotlib
matplotlib.use("Agg")

# import the necessary packages
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import argparse
import pickle
import cv2
import os
import random

# %% [markdown]
# ## New Additions and Corrections

# %%
# Defining the architectures of the first and second layers for temporal convolutions

first_layer = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters = 64, kernel_size = (3, 3), strides = 1, input_shape = (454, 454, 3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D(pool_size = (2, 2))
])

second_layer = tf.keras.models.Sequential([
    # input_shape needs to be fixed
    tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3), strides = 1, input_shape = first_layer.output.shape[1:]),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D(pool_size = (2, 2))
])

first_layer.summary()
second_layer.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 452, 452, 64)      1792
# _________________________________________________________________
# batch_normalization (BatchNo (None, 452, 452, 64)      256
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 226, 226, 64)      0
# =================================================================
# Total params: 2,048
# Trainable params: 1,920
# Non-trainable params: 128
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 224, 224, 32)      18464
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 224, 224, 32)      128
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 112, 112, 32)      0
# =================================================================
# Total params: 18,592
# Trainable params: 18,528
# Non-trainable params: 64
# _________________________________________________________________

# %%
def getFusedData(clipData, plot, path, clipName):
    output = []
    flag = 0
    curr = 0
    tenFrames = []
    
    # Loop for each 10 frames in a video clip
    while ((curr + 10) <= len(clipData)):
        tenFrames = clipData[curr : (curr + 10)]
        # print("Tenframes length: ", len(tenFrames))
        # print("Curr: ", curr)

        batch_1 = tenFrames[0 : 4]
        batch_2 = tenFrames[2 : 6]
        batch_3 = tenFrames[4 : 8]
        batch_4 = tenFrames[6 : 10]
        curr += 10

        # Figure out how to input 4 images at once to first_layer
        batch_1_1 = np.stack(np.array(batch_1), axis = 0)
        batch_1_2 = np.stack(np.array(batch_2), axis = 0)
        batch_1_3 = np.stack(np.array(batch_3), axis = 0)
        batch_1_4 = np.stack(np.array(batch_4), axis = 0)

        # print("Input shape: ", batch_1_1.shape)

        out_1_1 = first_layer(batch_1_1)
        out_1_2 = first_layer(batch_1_2)
        out_1_3 = first_layer(batch_1_3)
        out_1_4 = first_layer(batch_1_4)

        # print("First layer output shape: ", out_1_1.shape)
            
        # Plotting the output of the first layer
        if plot:
            square = 4
            ix = 1
            for _ in range(square):
                for _ in range(square):
                    # specify subplot and turn of axis
                    plt.figure(figsize = [20, 10])
                    # plt.title("First Layer Output Maps")
                    ax = plt.subplot(square, square, ix)
                    ax.set_xticks([])
                    ax.set_yticks([])
                    # plot filter channel in grayscale
                    # yplot.imshow(feature_maps[0, :, :, ix-1], cmap='gray')
                    plt.imshow(out_1_1[0, :, :, ix-1])
                    ix += 1

        batch_2_1 = np.concatenate([out_1_1, out_1_2])
        batch_2_2 = np.concatenate([out_1_3, out_1_4])

        # print("Batch_2_1 shape: ", batch_2_1.shape)

        out_2_1 = second_layer(batch_2_1)
        out_2_2 = second_layer(batch_2_2)
            
        # Plotting the output of the second layer
        if plot:
            plot = False
            square = 4
            ix = 1
            for _ in range(square):
                for _ in range(square):
                    # specify subplot and turn of axis
                    plt.figure(figsize = [20, 10])
                    plt.title("Second Layer Output Maps")
                    ax = plt.subplot(square, square, ix)
                    ax.set_xticks([])
                    ax.set_yticks([])
                    # plot filter channel in grayscale
                    # yplot.imshow(feature_maps[0, :, :, ix-1], cmap='gray')
                    plt.imshow(out_1_1[0, :, :, ix-1])
                    ix += 1
                
        output_map = np.concatenate([out_2_1, out_2_2])

        if (flag == 0):
            # print("Output map dimensions: ", output_map.shape)
            flag = 1

        output.append(output_map)

        if (path != None):
            # Saving the output numpy array
            filename = clipName + '_' + str(curr) + '.npy'
            with open(filename, 'wb') as f:
                np.save(f, output_map)
    
    return output

# %%
# Plotting images and outputs of intermediate layers

import matplotlib.pyplot as plt
import matplotlib.image as pltimg
# %matplotlib inline
plt.rcParams.update({'figure.max_open_warning': 0})

# Plot images, their outputs after the first and second layer
# One image

plt.figure()
label = str(input("Enter the label: "))
plt.xticks([])
plt.yticks([])
imagePath = 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\' + label
imagePaths = list(paths.list_images(imagePath))
image = pltimg.imread(imagePaths[0])

plt.imshow(image)
plt.title(label)

# Ten images in sequence
i = 0
images_list = []
plt.figure(figsize = [15, 7])
for images in imagePaths[:10]:
    plt.subplot(2, 5, (i + 1))
    image = pltimg.imread(images)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(image)
    i += 1
    
    image = cv2.imread(images)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (454, 454))
    images_list.append(image)
    
# Output after first layer
# Output after second layer
_ = getFusedData(images_list, True, None, None)
# Out:
# Enter the label: Abuse

# %%
import os

LABELS = set(["Abuse", "Assault", "Fighting", "Normal", "Robbery", "Vandalism"])
imgPath = 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated'
imagePaths = list(paths.list_images(r'C:\Users\Yash Umale\Documents\7th Sem\Research Paper\Datasets\Annotated'))

labels = os.listdir(imgPath)
lb = []
out = []

forOutputImage = []
forOutputLabel = []
forOutputMap = []

os.mkdir(r'C:\Users\Yash Umale\Documents\7th Sem\Research Paper\Datasets\Output_Maps')
os.chdir(r'C:\Users\Yash Umale\Documents\7th Sem\Research Paper\Datasets\Output_Maps')

for label in labels:
    print("--------- Adding ", label, " datasets ---------\n")
    labelClipPath = imgPath + '/' + label
    forOutputLabel.append(label)
    addOutput = 0
    addOutputMap = 0

    # Check if directory exists
    outputPath = 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Output_Maps\\' + label
    os.mkdir(outputPath)
      
    clips = os.listdir(labelClipPath)
    k = 1
    for clip in clips:
        print("Clip No.: ", k)
        clipData = []
        realImagePaths = list(paths.list_images(labelClipPath + '\\' + clip))
        
        for imagePath in realImagePaths:
            image = cv2.imread(imagePath)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, (454, 454))
            clipData.append(image)

            if (addOutput == 0):
                addOutput = 1
                forOutputImage.append(image)
        
        # Check if directory exists
        finalOutputPath = outputPath + '\\' + clip
        os.mkdir(finalOutputPath)
        os.chdir(finalOutputPath)

        output_maps = getFusedData(clipData, False, finalOutputPath, clip)
        
        if (addOutputMap == 0):
            addOutputMap = 1
            forOutputMap.append(output_maps[0])

        # lb += ([realImagePaths[-2]] * len(output_maps))
        # out += output_maps
        del clipData
        del output_maps
        k += 1

    print("--------- ", label, " datasets added. ---------\n")
# Out:
# --------- Adding  Abuse  datasets ---------
#
# Clip No.:  1
# Clip No.:  2
# Clip No.:  3
# Clip No.:  4
# Clip No.:  5
# Clip No.:  6
# Clip No.:  7
# Clip No.:  8
# Clip No.:  9
# Clip No.:  10
# Clip No.:  11
# Clip No.:  12
# Clip No.:  13
# Clip No.:  14
# Clip No.:  15
# Clip No.:  16
# Clip No.:  17
# Clip No.:  18
# Clip No.:  19
# Clip No.:  20
# Clip No.:  21
# Clip No.:  22
# Clip No.:  23
# Clip No.:  24
# Clip No.:  25
# ---------  Abuse  datasets added. ---------
#
# --------- Adding  Fighting  datasets ---------
#
# Clip No.:  1
# Clip No.:  2
# Clip No.:  3
# Clip No.:  4
# Clip No.:  5
# Clip No.:  6
# Clip No.:  7
# Clip No.:  8
# Clip No.:  9
# Clip No.:  10
# Clip No.:  11
# Clip No.:  12
# Clip No.:  13
# Clip No.:  14
# Clip No.:  15
# Clip No.:  16
# Clip No.:  17
# Clip No.:  18
# Clip No.:  19
# Clip No.:  20
# Clip No.:  21
# Clip No.:  22
# Clip No.:  23
# Clip No.:  24
# Clip No.:  25
# Clip No.:  26
# Clip No.:  27
# Clip No.:  28
# Clip No.:  29
# Clip No.:  30
# Clip No.:  31
# Clip No.:  32
# Clip No.:  33
# Clip No.:  34
# Clip No.:  35
# Clip No.:  36
# Clip No.:  37
# Clip No.:  38
# Clip No.:  39
# Clip No.:  40
# Clip No.:  41
# Clip No.:  42
# Clip No.:  43
# Clip No.:  44
# Clip No.:  45
# Clip No.:  46
# Clip No.:  47
# ---------  Fighting  datasets added. ---------
#
# --------- Adding  Normal  datasets ---------
#
# Clip No.:  1
# Clip No.:  2
# Clip No.:  3
# Clip No.:  4
# Clip No.:  5
# Clip No.:  6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ebb54e8b73ae> in <module>
#      49         os.chdir(finalOutputPath)
#      50
# ---> 51         output_maps = getFusedData(clipData, False, finalOutputPath, clip)
#      52
#      53         if (addOutputMap == 0):
#
# <ipython-input-3-71a82cb57338> in getFusedData(clipData, plot, path, clipName)
#      55
#      56         out_2_1 = second_layer(batch_2_1)
# ---> 57         out_2_2 = second_layer(batch_2_2)
#      58
#      59         # Plotting the output of the second layer
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1028         with autocast_variable.enable_auto_cast_variables(
#    1029             self._compute_dtype_object):
# -> 1030           outputs = call_fn(inputs, *args, **kwargs)
#    1031
#    1032         if self._activity_regularizer:
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\sequential.py in call(self, inputs, training, mask)
#     378       if not self.built:
#     379         self._init_graph_network(self.inputs, self.outputs)
# --> 380       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     381
#     382     outputs = inputs  # handle the corner case where self.layers is empty
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\functional.py in call(self, inputs, training, mask)
#     418         a list of tensors if there are more than one outputs.
#     419     """
# --> 420     return self._run_internal_graph(
#     421         inputs, training=training, mask=mask)
#     422
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\functional.py in _run_internal_graph(self, inputs, training, mask)
#     554
#     555         args, kwargs = node.map_arguments(tensor_dict)
# --> 556         outputs = node.layer(*args, **kwargs)
#     557
#     558         # Update tensor_dict.
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1028         with autocast_variable.enable_auto_cast_variables(
#    1029             self._compute_dtype_object):
# -> 1030           outputs = call_fn(inputs, *args, **kwargs)
#    1031
#    1032         if self._activity_regularizer:
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\layers\convolutional.py in call(self, inputs)
#     247       inputs = array_ops.pad(inputs, self._compute_causal_padding(inputs))
#     248
# --> 249     outputs = self._convolution_op(inputs, self.kernel)
#     250
#     251     if self.use_bias:
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\nn_ops.py in convolution_v2(input, filters, strides, padding, data_format, dilations, name)
#    1010     dilations=None,
#    1011     name=None):
# -> 1012   return convolution_internal(
#    1013       input,  # pylint: disable=redefined-builtin
#    1014       filters,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\nn_ops.py in convolution_internal(input, filters, strides, padding, data_format, dilations, name, call_from_convolution, num_spatial_dims)
#    1140         op = conv1d
#    1141
# -> 1142       return op(
#    1143           input,
#    1144           filters,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\nn_ops.py in _conv2d_expanded_batch(input, filters, strides, padding, data_format, dilations, name)
#    2594     # We avoid calling squeeze_batch_dims to reduce extra python function
#    2595     # call slowdown in eager mode.  This branch doesn't require reshapes.
# -> 2596     return gen_nn_ops.conv2d(
#    2597         input,
#    2598         filter=filters,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#     922   if tld.is_eager:
#     923     try:
# --> 924       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     925         _ctx, "Conv2D", name, input, filter, "strides", strides,
#     926         "use_cudnn_on_gpu", use_cudnn_on_gpu, "padding", padding,
#
# KeyboardInterrupt:

# %%
# Plot input and corresponding maps for comparison

for i in range(len(forOutputLabel)):
    plt.figure(figsize = [20, 10])
    plt.title(forOutputLabel[i])
    plt.subplot(1, 2, 1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(forOutputImage[i])

    plt.subplot(1, 2, 2)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(forOutputMap[i])

# %% [markdown]
# ## New Additions end here

# %%
'''LABELS = set(["Abuse", "Assault", "Fighting", "Normal", "Robbery", "Vandalism"])
imagePaths = list(paths.list_images(r'C:\Users\Yash Umale\Documents\7th Sem\Research Paper\Datasets\Annotated'))

data = []
labels = []
clipNos = []

init_clipNo = 1
clipData = []
old_label = ""
old_clipNo = 0

for imagePath in imagePaths:
    label = imagePath.split(os.path.sep)[-3]
    clipNo = imagePath.split(os.path.sep)[-2]
    
    if (clipNo != init_clipNo):
        init_clipNo = clipNo
        data.append(clipData)
        labels.append(old_label)
        clipNos.append(old_clipNo)
        clipData = []
        
        image = cv2.imread(imagePath)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = cv2.resize(image, (902, 902))
        clipData.append(image)
    else:
        old_clipNo = clipNo
        old_label = label
        
        image = cv2.imread(imagePath)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = cv2.resize(image, (902, 902))
        clipData.append(image)
    
data.append(clipData)
labels.append(old_label)
clipNos.append(old_clipNo)'''
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-3df619966c54> in <module>
#      30         old_label = label
#      31
# ---> 32         image = cv2.imread(imagePath)
#      33         image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#      34         image = cv2.resize(image, (902, 902))
#
# error: OpenCV(4.5.1) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-wvn_it83\opencv\modules\core\src\alloc.cpp:73: error: (-4:Insufficient memory) Failed to allocate 6220800 bytes in function 'cv::OutOfMemoryError'

# %%
output = []
lb = []
flag = 0

# Loop for each video clip in the entire dataset
for i in range(len(data)):
    curr = 0
    tenFrames = []
    label = labels[i]
    
    # Loop for each 10 frames in a video clip
    while ((curr + 10) < len(data[i])):
        lb.append(label)
        tenFrames = data[i][curr : (curr + 10)]
        
        batch_1 = tenFrames[curr : curr + 4]
        batch_2 = tenFrames[curr + 2 : curr + 6]
        batch_3 = tenFrames[curr + 4 : curr + 8]
        batch_4 = tenFrames[curr + 6 : curr + 10]
        curr += 10
        
        # Figure out how to input 4 images at once to first_layer
        batch_1_1 = np.stack(np.array(batch_1), axis = 0)
        batch_1_2 = np.stack(np.array(batch_2), axis = 0)
        batch_1_3 = np.stack(np.array(batch_3), axis = 0)
        batch_1_4 = np.stack(np.array(batch_4), axis = 0)
        
        print("Input shape: ", batch_1_1.shape)
        
        # batch_1_1 = batch_1_1.reshape(4, 224, 224, 3)
        # batch_1_2 = batch_1_2.reshape(4, 224, 224, 3)
        # batch_1_3 = batch_1_3.reshape(4, 224, 224, 3)
        # batch_1_4 = batch_1_4.reshape(4, 224, 224, 3)
        
        out_1_1 = first_layer(batch_1_1)
        out_1_2 = first_layer(batch_1_2)
        out_1_3 = first_layer(batch_1_3)
        out_1_4 = first_layer(batch_1_4)
        
        print("First layer output shape: ", out_1_1.shape)
        
        batch_2_1 = np.concatenate([out_1_1, out_1_2])
        batch_2_2 = np.concatenate([out_1_3, out_1_4])
        
        print("Batch_2_1 shape: ", batch_2_1.shape)
        
        out_2_1 = second_layer(batch_2_1)
        out_2_2 = second_layer(batch_2_2)
        output_map = np.concatenate([out_2_1, out_2_2])
        
        if (flag == 0):
            print("Output map dimensions: ", output_map.shape)
            flag = 1
            
        output.append(output_map)
# Out:
# Input shape:  (4, 224, 224, 3)
# First layer output shape:  (4, 31, 31, 64)
# Batch_2_1 shape:  (8, 31, 31, 64)
# Output map dimensions:  (16, 4, 4, 32)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-06294c6ebaad> in <module>
#      21
#      22         # Figure out how to input 4 images at once to first_layer
# ---> 23         batch_1_1 = np.stack(np.array(batch_1), axis = 0)
#      24         batch_1_2 = np.stack(np.array(batch_2), axis = 0)
#      25         batch_1_3 = np.stack(np.array(batch_3), axis = 0)
#
# <__array_function__ internals> in stack(*args, **kwargs)
#
# c:\users\yash umale\appdata\local\programs\python\python39\lib\site-packages\numpy\core\shape_base.py in stack(arrays, axis, out)
#     421     arrays = [asanyarray(arr) for arr in arrays]
#     422     if not arrays:
# --> 423         raise ValueError('need at least one array to stack')
#     424
#     425     shapes = {arr.shape for arr in arrays}
#
# ValueError: need at least one array to stack

# %%
LABELS = set(["Abuse", "Assault", "Fighting", "Normal", "Robbery", "Vandalism"])
imagePaths = list(paths.list_images(r'C:\Users\Yash Umale\Documents\7th Sem\Research Paper\Datasets\Annotated'))

data = []
labels = []
clipNos = []

init_clipNo = 1
clipData = []
old_label = ""
old_clipNo = 0

for imagePath in imagePaths:
    label = imagePath.split(os.path.sep)[-3]
    clipNo = imagePath.split(os.path.sep)[-2]
    
    if (clipNo != init_clipNo):
        init_clipNo = clipNo
        data.append(clipData)
        labels.append(old_label)
        clipNos.append(old_clipNo)
        clipData = []
        
        image = cv2.imread(imagePath)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = cv2.resize(image, (902, 902))
        clipData.append(image)
    else:
        old_clipNo = clipNo
        old_label = label
        
        image = cv2.imread(imagePath)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = cv2.resize(image, (902, 902))
        clipData.append(image)
    
data.append(clipData)
labels.append(old_label)
clipNos.append(old_clipNo)

# %% [markdown]
# ## Start here

# %%
# Defining the architectures of the first and second layers for temporal convolutions

first_layer = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters = 64, kernel_size = (3, 3), strides = 1, input_shape = (262, 262, 3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D(pool_size = (2, 2))
])

second_layer = tf.keras.models.Sequential([
    # input_shape needs to be fixed
    tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3), strides = 1, input_shape = first_layer.output.shape[1:]),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D(pool_size = (2, 2))
])

first_layer.summary()
second_layer.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 260, 260, 64)      1792
# _________________________________________________________________
# batch_normalization (BatchNo (None, 260, 260, 64)      256
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 130, 130, 64)      0
# =================================================================
# Total params: 2,048
# Trainable params: 1,920
# Non-trainable params: 128
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      18464
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 32)      128
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 64, 64, 32)        0
# =================================================================
# Total params: 18,592
# Trainable params: 18,528
# Non-trainable params: 64
# _________________________________________________________________

# %%
def getFusedData(clipData, plot):
    output = []
    for i in range(len(clipData)):
        curr = 0
        tenFrames = []
    
        # Loop for each 10 frames in a video clip
        while ((curr + 10) <= len(clipData)):
            tenFrames = clipData[curr : (curr + 10)]

            batch_1 = tenFrames[0 : 4]
            batch_2 = tenFrames[2 : 6]
            batch_3 = tenFrames[4 : 8]
            batch_4 = tenFrames[6 : 10]
            curr += 10

            # Figure out how to input 4 images at once to first_layer
            batch_1_1 = np.stack(np.array(batch_1), axis = 0)
            batch_1_2 = np.stack(np.array(batch_2), axis = 0)
            batch_1_3 = np.stack(np.array(batch_3), axis = 0)
            batch_1_4 = np.stack(np.array(batch_4), axis = 0)

            print("Input shape: ", batch_1_1.shape)

            out_1_1 = first_layer(batch_1_1)
            out_1_2 = first_layer(batch_1_2)
            out_1_3 = first_layer(batch_1_3)
            out_1_4 = first_layer(batch_1_4)

            print("First layer output shape: ", out_1_1.shape)
            
            # Plotting the output of the first layer
            if plot:
                square = 8
                ix = 1
                for _ in range(square):
                    for _ in range(square / 2):
                        # specify subplot and turn of axis
                        ax = plt.subplot(square, square / 2, ix)
                        # plot filter channel in grayscale
                        # yplot.imshow(feature_maps[0, :, :, ix-1], cmap='gray')
                        pyplot.imshow(out_1_1[0, :, :, ix-1])
                        ix += 1

            batch_2_1 = np.concatenate([out_1_1, out_1_2])
            batch_2_2 = np.concatenate([out_1_3, out_1_4])

            print("Batch_2_1 shape: ", batch_2_1.shape)

            out_2_1 = second_layer(batch_2_1)
            out_2_2 = second_layer(batch_2_2)
            
            # Plotting the output of the second layer
            if plot:
                plot = False
                square = 8
                ix = 1
                for _ in range(square):
                    for _ in range(square):
                        # specify subplot and turn of axis
                        ax = plt.subplot(square, square, ix)
                        # plot filter channel in grayscale
                        # yplot.imshow(feature_maps[0, :, :, ix-1], cmap='gray')
                        pyplot.imshow(out_1_1[0, :, :, ix-1])
                        ix += 1
                
            output_map = np.concatenate([out_2_1, out_2_2])

            if (flag == 0):
                print("Output map dimensions: ", output_map.shape)
                flag = 1

            output.append(output_map)
    
    return output

# %%
LABELS = set(["Abuse", "Assault", "Fighting", "Normal", "Robbery", "Vandalism"])
imgPath = 'C:\Users\Yash Umale\Documents\7th Sem\Research Paper\Datasets\Annotated'
imagePaths = list(paths.list_images(r'C:\Users\Yash Umale\Documents\7th Sem\Research Paper\Datasets\Annotated'))

labels = os.listdir(imagePaths)
lb = []
out = []
for label in labels:
    labelClipPath = imgPath + '\\' + label
    
    clips = os.listdir(labelClipPath)
    for clip in clips:
        clipData = []
        realImagePaths = list(paths.list_images(labelClipPath + '\\' + clip))
        
        for imagePath in realImagePaths:
            image = cv2.imread(imagePath)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, (902, 902))
            clipData.append(image)
        
        output_maps = getFusedOutput(clipData, False)
        lb += ([realImagePaths[-2]] * len(output_maps))
        out += output_maps

# %% [markdown]
# ## Plot the input and output images

# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimg

# Plot images, their outputs after the first and second layer
# One image

plt.figure()
label = str(input("Enter the label: "))
imagePath = 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\' + label
imagePaths = list(paths.list_images(imagePath))
image = pltimg.imread(imagePaths[0])

plt.imshow(image)
plt.title(label)

# Ten images in sequence
i = 0
images_list = []
for images in imagePaths[:10]:
    plt.subplot(2, 5, (i + 1))
    image = pltimg.imread(images)
    plt.imshow(image)
    i += 1
    
    image = cv2.imread(images)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (902, 902))
    images_list.append(image)
    
# Output after first layer
# Output after second layer
_ = getFusedData(images_list, True)
# Out:
# Enter the label: Abuse
# Input shape:  (4, 902, 902, 3)
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-12-37a5dfb0bcf2> in <module>
#      30 # Output after first layer
#      31 # Output after second layer
# ---> 32 _ = getFusedData(images_list, True)
#
# <ipython-input-3-78d11f66aaa9> in getFusedData(clipData, plot)
#      23             print("Input shape: ", batch_1_1.shape)
#      24
# ---> 25             out_1_1 = first_layer(batch_1_1)
#      26             out_1_2 = first_layer(batch_1_2)
#      27             out_1_3 = first_layer(batch_1_3)
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1028         with autocast_variable.enable_auto_cast_variables(
#    1029             self._compute_dtype_object):
# -> 1030           outputs = call_fn(inputs, *args, **kwargs)
#    1031
#    1032         if self._activity_regularizer:
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\sequential.py in call(self, inputs, training, mask)
#     378       if not self.built:
#     379         self._init_graph_network(self.inputs, self.outputs)
# --> 380       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     381
#     382     outputs = inputs  # handle the corner case where self.layers is empty
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\functional.py in call(self, inputs, training, mask)
#     418         a list of tensors if there are more than one outputs.
#     419     """
# --> 420     return self._run_internal_graph(
#     421         inputs, training=training, mask=mask)
#     422
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\functional.py in _run_internal_graph(self, inputs, training, mask)
#     554
#     555         args, kwargs = node.map_arguments(tensor_dict)
# --> 556         outputs = node.layer(*args, **kwargs)
#     557
#     558         # Update tensor_dict.
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1028         with autocast_variable.enable_auto_cast_variables(
#    1029             self._compute_dtype_object):
# -> 1030           outputs = call_fn(inputs, *args, **kwargs)
#    1031
#    1032         if self._activity_regularizer:
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\layers\convolutional.py in call(self, inputs)
#     247       inputs = array_ops.pad(inputs, self._compute_causal_padding(inputs))
#     248
# --> 249     outputs = self._convolution_op(inputs, self.kernel)
#     250
#     251     if self.use_bias:
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\nn_ops.py in convolution_v2(input, filters, strides, padding, data_format, dilations, name)
#    1010     dilations=None,
#    1011     name=None):
# -> 1012   return convolution_internal(
#    1013       input,  # pylint: disable=redefined-builtin
#    1014       filters,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\nn_ops.py in convolution_internal(input, filters, strides, padding, data_format, dilations, name, call_from_convolution, num_spatial_dims)
#    1140         op = conv1d
#    1141
# -> 1142       return op(
#    1143           input,
#    1144           filters,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\nn_ops.py in _conv2d_expanded_batch(input, filters, strides, padding, data_format, dilations, name)
#    2594     # We avoid calling squeeze_batch_dims to reduce extra python function
#    2595     # call slowdown in eager mode.  This branch doesn't require reshapes.
# -> 2596     return gen_nn_ops.conv2d(
#    2597         input,
#    2598         filter=filters,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#     929       return _result
#     930     except _core._NotOkStatusException as e:
# --> 931       _ops.raise_from_not_ok_status(e, name)
#     932     except _core._FallbackException:
#     933       pass
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\ops.py in raise_from_not_ok_status(e, name)
#    6895   message = e.message + (" name: " + name if name is not None else "")
#    6896   # pylint: disable=protected-access
# -> 6897   six.raise_from(core._status_to_exception(e.code, message), None)
#    6898   # pylint: enable=protected-access
#    6899
#
# c:\users\yash umale\appdata\local\programs\python\python39\lib\site-packages\six.py in raise_from(value, from_value)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[4,64,900,900] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:Conv2D]

# %% [markdown]
# ## Adding a new Generator for training

# %%
# Define a generator to feed images batchwise
import random 

input_shape = 0

def inputGenerator(batch_size, imagePaths, shuffle_data = True):
    num_samples = len(imagePaths)

    # Never let StopIteration occur
    while True:
        if (shuffle_data):
            random.shuffle(imagePaths)
            
        for offset in range(0, num_samples, batch_size):
            batch_samples = imagePaths[offset : (offset + batch_size)]

            X_train, y_train = [], []

            for batch_sample in batch_samples:
                img_path = batch_sample[0]
                label = batch_sample[1]

                image = np.load(img_path)

                X_train.append(image)
                y_train.append(label)

            X_train = np.array(X_train)
            y_train = np.array(y_train)

            yield X_train, y_train

# %%
# Calling the generator

imgPaths = []
inputData = "C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Output_Maps\\64 x 64"
images = []
lbls = []
arrPaths = []

for labelFolder in os.listdir(inputData):
    for clip in os.listdir((inputData + "\\" + labelFolder)):
        for output_map in os.listdir((inputData + "\\" + labelFolder + "\\" + clip)):
            arrPaths.append([(inputData + "\\" + labelFolder + "\\" + clip + "\\" + output_map), labelFolder])
            images.append((inputData + "\\" + labelFolder + "\\" + clip + "\\" + output_map))
            lbls.append(labelFolder)
    imgPaths.append(arrPaths)

imgPaths = np.array(imgPaths)

# Creating train and test subsets
lbBinarizer = LabelBinarizer()
lbls = lbBinarizer.fit_transform(lbls)
(x_train, x_test, y_train, y_test) = train_test_split(images, lbls, test_size = 0.25, shuffle = True, stratify = None, random_state = 42)

# %%
print(np.load(x_train[0]))
# Out:
# [[[[-1.12056618e+01  2.85171204e+01 -2.83905053e+00 ...  8.86169529e+00
#      1.38294582e+01 -2.26144600e+01]
#    [-2.87919102e+01  3.55235901e+01  6.03950214e+00 ...  9.34631348e+00
#      1.76564121e+01 -1.58253202e+01]
#    [-2.58804703e+01  3.49803963e+01  5.03590107e+00 ...  9.35632515e+00
#      1.65784779e+01 -1.38621330e+01]
#    ...
#    [-1.02451859e+01  1.43031673e+01  3.84803200e+00 ...  5.83548355e+00
#      9.19262505e+00 -2.46171427e+00]
#    [-1.04496574e+01  1.38336267e+01  3.64684534e+00 ...  5.26605797e+00
#      8.85203552e+00 -2.45057797e+00]
#    [-1.02698174e+01  1.37546329e+01  3.78128624e+00 ...  5.44343662e+00
#      8.92053413e+00 -2.50372982e+00]]
#
#   [[-1.24662838e+01  2.90419064e+01 -3.02200413e+00 ...  8.95558167e+00
#      1.32330933e+01 -2.29870834e+01]
#    [-2.84608498e+01  3.62224503e+01  5.99149513e+00 ...  9.29573154e+00
#      1.71897774e+01 -1.55885448e+01]
#    [-2.69371834e+01  3.59434509e+01  5.72581577e+00 ...  9.26122665e+00
#      1.75369167e+01 -1.51115751e+01]
#    ...
#    [-1.07095480e+01  1.51688709e+01  4.80094719e+00 ...  5.81118727e+00
#      9.33123207e+00 -3.16010594e+00]
#    [-1.10167170e+01  1.42419701e+01  4.65183783e+00 ...  5.65403175e+00
#      9.51814079e+00 -2.92669106e+00]
#    [-1.01281090e+01  1.40188437e+01  4.11960840e+00 ...  5.78338337e+00
#      9.31090260e+00 -2.13264990e+00]]
#
#   [[-1.31408768e+01  2.91817112e+01 -2.35727930e+00 ...  9.29528809e+00
#      1.31085930e+01 -2.32128792e+01]
#    [-2.77574711e+01  3.63260994e+01  6.29538965e+00 ...  9.20079041e+00
#      1.71673355e+01 -1.61416893e+01]
#    [-2.78890953e+01  3.67713623e+01  5.49030781e+00 ...  9.69888783e+00
#      1.72053375e+01 -1.59006157e+01]
#    ...
#    [-1.08832741e+01  1.48233681e+01  5.38485909e+00 ...  6.28011560e+00
#      9.56044388e+00 -3.68863630e+00]
#    [-1.04750347e+01  1.51549845e+01  4.76682377e+00 ...  5.89962006e+00
#      1.02380533e+01 -2.56577945e+00]
#    [-1.07736425e+01  1.53215942e+01  4.70751381e+00 ...  6.34297991e+00
#      1.07241440e+01 -1.95503736e+00]]
#
#   ...
#
#   [[-3.68421936e+00  5.28954458e+00  2.27826309e+00 ...  3.70373631e+00
#    [-2.44410157e+00  4.36695385e+00  1.18869913e+00 ...  2.36621690e+00
#      2.38699555e+00  2.54791975e-01]]
#
#   [[-8.06913078e-01  1.82994614e+01 -6.01047325e+00 ...  7.17155361e+00
#      4.03713274e+00 -1.11337900e-02]
#    [-4.59122419e+00  1.75872593e+01 -4.63689756e+00 ...  7.02576303e+00
#      9.50958157e+00  1.33133612e+01]
#    [ 7.50490427e+00  1.40501785e+01 -2.25831032e+00 ...  3.72222662e+00
#      1.20236740e+01 -1.47559333e+00]
#    ...
#    [-4.57397890e+00  4.82066441e+00  1.53643715e+00 ...  1.97036004e+00
#      4.03888655e+00  5.31077266e-01]
#    [-3.22759271e+00  4.40615940e+00  1.73484111e+00 ...  2.50892305e+00
#      3.10242081e+00 -1.47589639e-01]
#    [-2.78400421e+00  4.73851299e+00  1.74195623e+00 ...  2.36967945e+00
#      3.27735972e+00 -9.32771415e-02]]
#
#   [[-6.63616371e+00  2.37017956e+01 -8.16357327e+00 ...  6.61791372e+00
#      8.75404549e+00 -1.06987219e+01]
#    [-1.72792397e+01  2.65792503e+01 -1.56479609e+00 ...  7.52622747e+00
#      1.35529947e+01 -1.07026756e+00]
#    [-8.55454159e+00  2.39507160e+01 -2.69430208e+00 ...  3.07332611e+00
#      1.41977406e+01 -5.72538567e+00]
#    ...
#    [-5.01691532e+00  5.53889656e+00  1.46641707e+00 ...  2.84550738e+00
#      4.03503513e+00  8.38770032e-01]
#    [-3.21531892e+00  5.65693235e+00  1.52005410e+00 ...  3.18055248e+00
#      3.95621634e+00  6.36936307e-01]
#    [-3.24116087e+00  6.18563938e+00  1.54210329e+00 ...  3.37316322e+00
#      4.07235098e+00  3.32371205e-01]]]]

# %%
gen_train = []
gen_test = []

for i in range(len(x_train)):
    gen_train.append([x_train[i], y_train[i]])

for i in range(len(x_test)):
    gen_test.append([x_test[i], y_test[i]])

batchSize = 4
train_generator = inputGenerator(batchSize, gen_train, True)
test_generator = inputGenerator(batchSize, gen_test, True)

# %%
print(len(gen_test))
print(len(gen_train))
# Out:
# 1041
# 3123

# %%
print(train_generator.__next__()[0].shape)
# Out:
# (4, 16, 64, 64, 32)

# %%
image = np.load('C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Output_Maps\\64 x 64\\Normal\\Normal_Videos_478_x264.mp4\\Normal_Videos_478_x264.mp4_240.npy')
print(image.shape)
print(image)
# Out:
# (16, 64, 64, 32)
# [[[[-3.92573476e-01  1.33460312e+01 -3.02178144e+00 ...  5.09141064e+00
#     -5.83599806e-02 -6.76578617e+00]
#    [-1.09002237e+01  1.25530472e+01 -2.20383000e+00 ...  2.32361388e+00
#      1.00466642e+01  3.11755466e+00]
#    [-4.02729464e+00  9.49203682e+00 -1.22617006e-01 ...  1.66489482e+00
#      5.35029411e+00 -5.55206251e+00]
#    ...
#    [-4.02259350e+00  5.41172314e+00  7.36327887e-01 ...  1.63970029e+00
#      1.37961805e+00 -2.94501519e+00]
#    [-4.06521034e+00  5.49686241e+00  7.08483815e-01 ...  1.77070451e+00
#      1.40498519e+00 -2.86027765e+00]
#      3.84915686e+00 -4.34894466e+00]
#    ...
#    [-1.77615070e+01  2.05497704e+01  8.51946259e+00 ...  6.41794109e+00
#      1.13569365e+01 -1.16630821e+01]
#    [-1.63569775e+01  2.09662380e+01  6.44132280e+00 ...  5.87589693e+00
#      1.06068296e+01 -1.32666969e+01]
#    [-2.03158474e+01  2.25228653e+01  5.89340782e+00 ...  6.47061396e+00
#      1.03371954e+01 -1.30816793e+01]]]]

# %% [markdown]
# ## Train the model

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
'''
main_data = np.array(out)
lbBinarizer = LabelBinarizer()
lb = lbBinarizer.fit_transform(lb)

(trainX, testX, trainY, testY) = train_test_split(data, lb, test_size = 0.25, stratify = labels, random_state = 42)

trainAug = ImageDataGenerator(rotation_range = 30,
                             zoom_range = 0.15,
                             width_shift_range = 0.2,
                             height_shift_range = 0.2,
                             shear_range = 0.15,
                             horizontal_flip = True,
                             fill_mode = "nearest")

valAug = ImageDataGenerator()

mean = np.array([123.68, 116.779, 103.939], dtype="float32")
trainAug.mean = mean
valAug.mean = mean
n_epochs = 50
'''

# %%
with tf.device('/gpu:0'):
    '''
    baseModel = ResNet50(weights = "imagenet", include_top = False,
        input_tensor = Input(shape = image.shape[1:]))
    '''
    n_epochs = 50
    batch_size = 4
    baseModel = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(filters = 64, kernel_size = (2, 2), strides = 1, input_shape = (64, 64, 32))])
        # tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3), strides = 1),
        # tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3), strides = 1),
        # tf.keras.layers.AveragePooling2D(pool_size = (2, 2))])

    headModel = baseModel.output
    headModel = AveragePooling2D(pool_size = (3, 3))(headModel)
    headModel = Flatten(name = "flatten")(headModel)
    headModel = Dense(512, activation = "relu")(headModel)
    headModel = Dropout(0.5)(headModel)
    headModel = Dense(len(lbBinarizer.classes_), activation = "softmax")(headModel)

    model = Model(inputs=baseModel.input, outputs=headModel)

    '''
    for layer in baseModel.layers:
        layer.trainable = False
    '''
    
    print("Compiling model:")
    opt = SGD(lr = 1e-4, momentum = 0.9, decay = (1e-4 / n_epochs))
    model.compile(loss = "categorical_crossentropy", optimizer = opt, metrics = [tf.keras.metrics.Accuracy(),
                                                                                 tf.keras.metrics.CategoricalAccuracy(),
                                                                                 tf.keras.metrics.TopKCategoricalAccuracy(),
                                                                                 tf.keras.metrics.Precision(),
                                                                                 tf.keras.metrics.Recall(), 
                                                                                 tf.keras.metrics.TruePositives(), 
                                                                                 tf.keras.metrics.TrueNegatives(), 
                                                                                 tf.keras.metrics.FalsePositives(), 
                                                                                 tf.keras.metrics.FalseNegatives()])

    '''
    print("Training head:")
    H = model.fit(
        x = trainAug.flow(trainX, trainY, batch_size = 32),
        steps_per_epoch = len(trainX) // 32,
        validation_data = valAug.flow(testX, testY),
        validation_steps = len(testX) // 32,
        epochs = n_epochs)
    
    
    H = model.fit(
        x = inputGenerator(4, x_train, True),
        steps_per_epoch = len(x_train) // 4,
        validation_data = inputGenerator(4, x_test, True),
        validation_steps = len(x_test) // 4,
        epochs = n_epochs)
    '''
    
    H = model.fit_generator(train_generator,
                           steps_per_epoch = len(gen_train) // 4,
                           epochs = n_epochs,
                           validation_data = test_generator,
                           validation_steps = len(gen_test) // 4)
# Out:
# Compiling model:
# Epoch 1/50
# WARNING:tensorflow:Model was constructed with shape (None, 64, 64, 32) for input KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 32), dtype=tf.float32, name='conv2d_4_input'), name='conv2d_4_input', description="created by layer 'conv2d_4_input'"), but it was called on an input with incompatible shape (None, None, None, None, None).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-e92d75094799> in <module>
#      56     '''
#      57
# ---> 58     H = model.fit_generator(train_generator,
#      59                            steps_per_epoch = len(gen_train) // 4,
#      60                            epochs = n_epochs,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1941                   'will be removed in a future version. '
#    1942                   'Please use `Model.fit`, which supports generators.')
# -> 1943     return self.fit(
#    1944         generator,
#    1945         steps_per_epoch=steps_per_epoch,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     931       # This is the first call of __call__, so we have to initialize.
#     932       initializers = []
# --> 933       self._initialize(args, kwds, add_initializers_to=initializers)
#     934     finally:
#     935       # At this point we know that the initialization is complete (or less
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     761     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     762     self._concrete_stateful_fn = (
# --> 763         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     764             *args, **kwds))
#     765
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3048       args, kwargs = None, None
#    3049     with self._lock:
# -> 3050       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3051     return graph_function
#    3052
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3442
#    3443           self._function_cache.missed.add(call_context_key)
# -> 3444           graph_function = self._create_graph_function(args, kwargs)
#    3445           self._function_cache.primary[cache_key] = graph_function
#    3446
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3277     arg_names = base_arg_names + missing_arg_names
#    3278     graph_function = ConcreteFunction(
# -> 3279         func_graph_module.func_graph_from_py_func(
#    3280             self._name,
#    3281             self._python_function,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     997         _, original_func = tf_decorator.unwrap(python_func)
#     998
# --> 999       func_outputs = python_func(*func_args, **func_kwargs)
#    1000
#    1001       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     670         # the function a weak reference to itself to avoid a reference cycle.
#     671         with OptionalXlaContext(compile_with_xla):
# --> 672           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673         return out
#     674
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\func_graph.py in wrapper(*args, **kwargs)
#     984           except Exception as e:  # pylint:disable=broad-except
#     985             if hasattr(e, "ag_error_metadata"):
# --> 986               raise e.ag_error_metadata.to_exception(e)
#     987             else:
#     988               raise
#
# ValueError: in user code:
#
#     C:\Users\Yash Umale\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\training.py:855 train_function  *
#         return step_function(self, iterator)
#     C:\Users\Yash Umale\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\training.py:845 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\Yash Umale\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\distribute\distribute_lib.py:1285 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\Yash Umale\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\distribute\distribute_lib.py:2833 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\Yash Umale\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\distribute\distribute_lib.py:3608 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\Yash Umale\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\training.py:838 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\Yash Umale\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\training.py:795 train_step
#         y_pred = self(x, training=True)
#     C:\Users\Yash Umale\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\base_layer.py:1030 __call__
#         outputs = call_fn(inputs, *args, **kwargs)
#     C:\Users\Yash Umale\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\functional.py:420 call
#         return self._run_internal_graph(
#     C:\Users\Yash Umale\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\functional.py:556 _run_internal_graph
#         outputs = node.layer(*args, **kwargs)
#     C:\Users\Yash Umale\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\base_layer.py:1013 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     C:\Users\Yash Umale\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\input_spec.py:215 assert_input_compatibility
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer average_pooling2d_6 is incompatible with the layer: expected ndim=4, found ndim=5. Full shape received: (None, None, None, None, 64)

# %%
# Evaluate the network
print("Evaluating network:")
predictions = model.predict(x = x_test.astype("float32"), batch_size = 32)

# To print precision, recall, F1 score
print(classification_report(y_test.argmax(axis = 1), predictions.argmax(axis = 1), target_names = lb.classes_))

# Plot the training loss and accuracy
N = n_epochs
plt.style.use("ggplot")

plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy on Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss/ Accuracy")
plt.legend(loc="lower left")

plotPath = r'C:\Users\Yash Umale\Documents\7th Sem\Research Paper\Plots'
plt.savefig(plotPath)

# %%
'''def getFusedData(clipData, plot):
    output = []
    for i in range(len(clipData)):
        curr = 0
        tenFrames = []
    
        # Loop for each 10 frames in a video clip
        while ((curr + 10) <= len(clipData)):
            tenFrames = clipData[curr : (curr + 10)]

            batch_1 = tenFrames[0 : 4]
            batch_2 = tenFrames[2 : 6]
            batch_3 = tenFrames[4 : 8]
            batch_4 = tenFrames[6 : 10]
            curr += 10

            # Figure out how to input 4 images at once to first_layer
            batch_1_1 = np.stack(np.array(batch_1), axis = 0)
            batch_1_2 = np.stack(np.array(batch_2), axis = 0)
            batch_1_3 = np.stack(np.array(batch_3), axis = 0)
            batch_1_4 = np.stack(np.array(batch_4), axis = 0)

            print("Input shape: ", batch_1_1.shape)

            out_1_1 = first_layer(batch_1_1)
            out_1_2 = first_layer(batch_1_2)
            out_1_3 = first_layer(batch_1_3)
            out_1_4 = first_layer(batch_1_4)

            print("First layer output shape: ", out_1_1.shape)
            
            # Plotting the output of the first layer
            if plot:
                square = 8
                ix = 1
                for _ in range(square):
                    for _ in range(square / 2):
                        # specify subplot and turn of axis
                        ax = plt.subplot(square, square / 2, ix)
                        # plot filter channel in grayscale
                        # yplot.imshow(feature_maps[0, :, :, ix-1], cmap='gray')
                        pyplot.imshow(out_1_1[0, :, :, ix-1])
                        ix += 1

            batch_2_1 = np.concatenate([out_1_1, out_1_2])
            batch_2_2 = np.concatenate([out_1_3, out_1_4])

            print("Batch_2_1 shape: ", batch_2_1.shape)

            out_2_1 = second_layer(batch_2_1)
            out_2_2 = second_layer(batch_2_2)
            
            # Plotting the output of the second layer
            if plot:
                plot = False
                square = 8
                ix = 1
                for _ in range(square):
                    for _ in range(square):
                        # specify subplot and turn of axis
                        ax = plt.subplot(square, square, ix)
                        # plot filter channel in grayscale
                        # yplot.imshow(feature_maps[0, :, :, ix-1], cmap='gray')
                        pyplot.imshow(out_1_1[0, :, :, ix-1])
                        ix += 1
                
            output_map = np.concatenate([out_2_1, out_2_2])

            if (flag == 0):
                print("Output map dimensions: ", output_map.shape)
                flag = 1

            output.append(output_map)
    
    return output'''

# %%
'''# Define a generator to feed images batchwise
import random 

input_shape = 0

def inputGenerator(batch_size, imagePaths):
    num_samples = len(imagePaths)
    
    for offset in range(0, num_samples, batch_size):
        batch_samples = imagePaths[offset : (offset + batch_size)]
        X_train, y_train = [], []
        tenFrames = []
        
        for batch_sample in batch_samples:
            label = batch_sample[1]
            
            for frame in batch_sample[0]:
                img_path = frame
                image = np.load(img_path)
                
            X_train.append(image)
            y_train.append(label)
            
        X_train = np.array(X_train)
        y_train = np.array(y_train)
        
        yield X_train, y_train

    # Never let StopIteration occur
    # while True:    '''

# %% [markdown]
# ## **Fresh Start, with new inputs**
#
# 1. Create the sequential models for fusion and the headModel.
# 2. Create a generator function.
# 3. Train and evaluate w.r.t. several metrics.

# %% [markdown]
# ## Model Architecture

# %%
# set the matplotlib backend so figures can be saved in the background
import matplotlib
matplotlib.use("Agg")

# import the necessary packages
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import argparse
import pickle
import cv2
import os
import random

# %%
# Calculate output feature map size

first_layer = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters = 64, kernel_size = (3, 3), strides = 1, input_shape = (902, 902, 3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D(pool_size = (2, 2))
])

second_layer = tf.keras.models.Sequential([
    # input_shape needs to be fixed
    tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3), strides = 1, input_shape = first_layer.output.shape[1:]),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D(pool_size = (2, 2))
])

# %%
first_layer.summary()
second_layer.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 900, 900, 64)      1792
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 900, 900, 64)      256
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 450, 450, 64)      0
# =================================================================
# Total params: 2,048
# Trainable params: 1,920
# Non-trainable params: 128
# _________________________________________________________________
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 448, 448, 32)      18464
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 448, 448, 32)      128
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 224, 224, 32)      0
# =================================================================
# Total params: 18,592
# Trainable params: 18,528
# Non-trainable params: 64
# _________________________________________________________________

# %%
import tensorflow.keras.utils 

tensorflow.keras.utils.plot_model(first_layer, 'first_layer.png')
tensorflow.keras.utils.plot_model(second_layer, 'second_layer.png')
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
def getFusedData(tenFramePaths):
    
    tenFrames = []
    for frameNumber in range(len(tenFramePaths)):
        temp_image = cv2.imread(tenFramePaths[frameNumber])
        temp_image = cv2.cvtColor(temp_image, cv2.COLOR_BGR2RGB)
        temp_image = cv2.resize(temp_image, (902, 902))
        tenFrames.append(temp_image)
    
    batch_1 = tenFrames[0 : 4]
    batch_2 = tenFrames[2 : 6]
    batch_3 = tenFrames[4 : 8]
    batch_4 = tenFrames[6 : 10]
    
    # Figure out how to input 4 images at once to first_layer
    batch_1_1 = np.stack(np.array(batch_1), axis = 0)
    batch_1_2 = np.stack(np.array(batch_2), axis = 0)
    batch_1_3 = np.stack(np.array(batch_3), axis = 0)
    batch_1_4 = np.stack(np.array(batch_4), axis = 0)
                         
    out_1_1 = first_layer(batch_1_1)
    out_1_2 = first_layer(batch_1_2)
    out_1_3 = first_layer(batch_1_3)
    out_1_4 = first_layer(batch_1_4)
                          
    batch_2_1 = np.concatenate([out_1_1, out_1_2])
    batch_2_2 = np.concatenate([out_1_3, out_1_4])
    
    out_2_1 = second_layer(batch_2_1)
    out_2_2 = second_layer(batch_2_2)
        
    output_map = np.concatenate([out_2_1, out_2_2])
    
    del tenFrames
    
    return output_map

# %%
# The real generator. Ignore the other codes.

def inputMapGenerator(batch_size, arrPaths, lbls):
    num_samples = len(arrPaths)
    
    while True:
    
        for offset in range(0, num_samples, batch_size):
            batch_samples = arrPaths[offset : (offset + batch_size)]
            X, Y = [], []

            batch_no = 0
            for batch_sample in batch_samples:
                label = lbls[offset + batch_no]
                batch_no += 1

                X.append(getFusedData(batch_sample))
                Y.append(label)
            
            yield X, Y

# %%
# Calling the generator

imgPaths = []
inputData = "C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated"
images = []
lbls = []
arrPaths = []
arrLbls = []
batch = []

for labelFolder in os.listdir(inputData):
    for clip in os.listdir((inputData + "\\" + labelFolder)):
        count = 0
        for frame in range(count, len(os.listdir((inputData + "\\" + labelFolder + "\\" + clip))), 10):
            tempArr = os.listdir((inputData + "\\" + labelFolder + "\\" + clip))[count : (count + 10)]
            for i in range(len(tempArr)):
                tempArr[i] = inputData + "\\" + labelFolder + "\\" + clip + "\\" + tempArr[i]
            arrPaths.append(tempArr)
            del tempArr
            # batch.append([os.listdir((inputData + "\\" + labelFolder + "\\" + clip))[count : (count + 10)], labelFolder])
            images.append(os.listdir((inputData + "\\" + labelFolder + "\\" + clip))[count : (count + 10)])
            lbls.append(labelFolder)
            count += 10
            
        
        '''
        for output_map in os.listdir((inputData + "\\" + labelFolder + "\\" + clip)):
            arrPaths.append([(inputData + "\\" + labelFolder + "\\" + clip + "\\" + output_map), labelFolder])
            images.append((inputData + "\\" + labelFolder + "\\" + clip + "\\" + output_map))
            lbls.append(labelFolder)
        '''
        
    imgPaths.append(arrPaths)
    arrLbls.append(lbls)
    
    # arrPaths and labelFolder

imgPaths = np.array(imgPaths)

# Creating train and test subsets
lbBinarizer = LabelBinarizer()
lbls = lbBinarizer.fit_transform(lbls)
# (x_train, x_test, y_train, y_test) = train_test_split(images, lbls, test_size = 0.25, shuffle = True, stratify = None, random_state = 42)
# Out:
# <ipython-input-9-e5e7f2a98182>:38: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   imgPaths = np.array(imgPaths)

# %%
print(arrPaths[:2])
# Out:
# [['C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_103.jpg', 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_109.jpg', 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_115.jpg', 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_121.jpg', 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_127.jpg', 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_13.jpg', 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_133.jpg', 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_139.jpg', 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_145.jpg', 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_151.jpg'], ['C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_157.jpg', 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_163.jpg', 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_169.jpg', 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_175.jpg', 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_181.jpg', 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_187.jpg', 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_19.jpg', 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_193.jpg', 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_199.jpg', 'C:\\Users\\Yash Umale\\Documents\\7th Sem\\Research Paper\\Datasets\\Annotated\\Abuse\\1.mp4\\Abuse_1.mp4_205.jpg']]

# %%
# arrPaths and lbls are the lists of interest
# arrPaths = [[imagePath1, imagePath2, ..., imagePath10], [imagePath1, imagePath2, ..., imagePath10] ... for all clips in video]
# lbls = [label1, label2, label3, ... for each 10-frame clip in video]

[x_train, x_test, y_train, y_test] = train_test_split(arrPaths, lbls, test_size = 0.25, shuffle = True, stratify = None)

# %%
batchSize = 1
train_generator = inputMapGenerator(batchSize, x_train, y_train)
test_generator = inputMapGenerator(batchSize, x_test, y_test)

# %%
timepass_x, timepass_y = next(train_generator)
print(timepass_x)
print("------------------------------------------------\n")
print(timepass_y)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-24-9736c9b2bae8> in <module>
# ----> 1 timepass_x, timepass_y = next(train_generator)
#       2 print(timepass_x)
#       3 print("------------------------------------------------\n")
#       4 print(timepass_y)
#
# <ipython-input-10-93984941acf2> in inputMapGenerator(batch_size, arrPaths, lbls)
#      15                 batch_no += 1
#      16
# ---> 17                 X.append(getFusedData(batch_sample))
#      18                 Y.append(label)
#      19
#
# <ipython-input-9-ac3c54df2171> in getFusedData(tenFramePaths)
#      19     batch_1_4 = np.stack(np.array(batch_4), axis = 0)
#      20
# ---> 21     out_1_1 = first_layer(batch_1_1)
#      22     out_1_2 = first_layer(batch_1_2)
#      23     out_1_3 = first_layer(batch_1_3)
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1028         with autocast_variable.enable_auto_cast_variables(
#    1029             self._compute_dtype_object):
# -> 1030           outputs = call_fn(inputs, *args, **kwargs)
#    1031
#    1032         if self._activity_regularizer:
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\sequential.py in call(self, inputs, training, mask)
#     378       if not self.built:
#     379         self._init_graph_network(self.inputs, self.outputs)
# --> 380       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     381
#     382     outputs = inputs  # handle the corner case where self.layers is empty
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\functional.py in call(self, inputs, training, mask)
#     418         a list of tensors if there are more than one outputs.
#     419     """
# --> 420     return self._run_internal_graph(
#     421         inputs, training=training, mask=mask)
#     422
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\functional.py in _run_internal_graph(self, inputs, training, mask)
#     554
#     555         args, kwargs = node.map_arguments(tensor_dict)
# --> 556         outputs = node.layer(*args, **kwargs)
#     557
#     558         # Update tensor_dict.
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1028         with autocast_variable.enable_auto_cast_variables(
#    1029             self._compute_dtype_object):
# -> 1030           outputs = call_fn(inputs, *args, **kwargs)
#    1031
#    1032         if self._activity_regularizer:
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\layers\convolutional.py in call(self, inputs)
#     247       inputs = array_ops.pad(inputs, self._compute_causal_padding(inputs))
#     248
# --> 249     outputs = self._convolution_op(inputs, self.kernel)
#     250
#     251     if self.use_bias:
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\nn_ops.py in convolution_v2(input, filters, strides, padding, data_format, dilations, name)
#    1010     dilations=None,
#    1011     name=None):
# -> 1012   return convolution_internal(
#    1013       input,  # pylint: disable=redefined-builtin
#    1014       filters,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\nn_ops.py in convolution_internal(input, filters, strides, padding, data_format, dilations, name, call_from_convolution, num_spatial_dims)
#    1140         op = conv1d
#    1141
# -> 1142       return op(
#    1143           input,
#    1144           filters,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\nn_ops.py in _conv2d_expanded_batch(input, filters, strides, padding, data_format, dilations, name)
#    2594     # We avoid calling squeeze_batch_dims to reduce extra python function
#    2595     # call slowdown in eager mode.  This branch doesn't require reshapes.
# -> 2596     return gen_nn_ops.conv2d(
#    2597         input,
#    2598         filter=filters,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#     929       return _result
#     930     except _core._NotOkStatusException as e:
# --> 931       _ops.raise_from_not_ok_status(e, name)
#     932     except _core._FallbackException:
#     933       pass
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\ops.py in raise_from_not_ok_status(e, name)
#    6895   message = e.message + (" name: " + name if name is not None else "")
#    6896   # pylint: disable=protected-access
# -> 6897   six.raise_from(core._status_to_exception(e.code, message), None)
#    6898   # pylint: enable=protected-access
#    6899
#
# c:\users\yash umale\appdata\local\programs\python\python39\lib\site-packages\six.py in raise_from(value, from_value)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[4,64,900,900] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:Conv2D]

# %%
'''# inputGenerator sends batch_size number of tenFrames with corresponding labels
# Each tenFrame needs to be split into 4 frames and concatenated after each layer

with tf.device('/gpu:0'):
    flag = True
    while flag:
        try:
            opts = []
            labs = []
            for i in range(batchSize):
                
                tenFrames_X, tenFrames_Y = next(train_generator)

                batch_1 = tenFrames_X[0 : 4]
                batch_2 = tenFrames_X[2 : 6]
                batch_3 = tenFrames_X[4 : 8]
                batch_4 = tenFrames_X[6 : 10]

                batch_1_1 = np.stack(np.array(batch_1), axis = 0)
                batch_1_2 = np.stack(np.array(batch_2), axis = 0)
                batch_1_3 = np.stack(np.array(batch_3), axis = 0)
                batch_1_4 = np.stack(np.array(batch_4), axis = 0)

                out_1_1 = first_layer(batch_1_1)
                out_1_2 = first_layer(batch_1_2)
                out_1_3 = first_layer(batch_1_3)
                out_1_4 = first_layer(batch_1_4)

                batch_2_1 = np.concatenate([out_1_1, out_1_2])
                batch_2_2 = np.concatenate([out_1_3, out_1_4])

                out_2_1 = second_layer(batch_2_1)
                out_2_2 = second_layer(batch_2_2)

                output_map = np.concatenate([out_2_1, out_2_2])
                opts.append(output_map)
                labs.append(tenFrames_Y)

            
            baseModel = ResNet50(weights = "imagenet", include_top = False,
                input_tensor = Input(shape = image.shape[1:]))
            
            n_epochs = 10
            
            
            batch_size = 4
            baseModel = tf.keras.models.Sequential([
                tf.keras.layers.Conv2D(filters = 64, kernel_size = (2, 2), strides = 1, input_shape = (64, 64, 32))])
                # tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3), strides = 1),
                # tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3), strides = 1),
                # tf.keras.layers.AveragePooling2D(pool_size = (2, 2))])
            

            headModel = baseModel.output
            headModel = AveragePooling2D(pool_size = (3, 3))(headModel)
            headModel = Flatten(name = "flatten")(headModel)
            headModel = Dense(512, activation = "relu")(headModel)
            headModel = Dropout(0.5)(headModel)
            headModel = Dense(len(lbBinarizer.classes_), activation = "softmax")(headModel)

            model = Model(inputs=baseModel.input, outputs=headModel)

            for layer in baseModel.layers:
                layer.trainable = False

            print("Compiling model:")
            opt = SGD(lr = 1e-4, momentum = 0.9, decay = (1e-4 / n_epochs))
            model.compile(loss = "categorical_crossentropy", optimizer = opt, metrics = [tf.keras.metrics.Accuracy(),
                                                                                         tf.keras.metrics.CategoricalAccuracy(),
                                                                                         tf.keras.metrics.TopKCategoricalAccuracy(),
                                                                                         tf.keras.metrics.Precision(),
                                                                                         tf.keras.metrics.Recall(), 
                                                                                         tf.keras.metrics.TruePositives(), 
                                                                                         tf.keras.metrics.TrueNegatives(), 
                                                                                         tf.keras.metrics.FalsePositives(), 
                                                                                         tf.keras.metrics.FalseNegatives()])
            
            H = model.fit(opts, labs, epochs = n_epochs)

        except StopIteration:
            flag = False'''

# %%
baseModel = ResNet50(weights = "imagenet", include_top = False, input_shape = second_layer.output.shape[1:])
baseModel.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-ea87377dc62e> in <module>
# ----> 1 baseModel = ResNet50(weights = "imagenet", include_top = False, input_shape = second_layer.output.shape[1:])
#       2 baseModel.summary()
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\applications\resnet.py in ResNet50(include_top, weights, input_tensor, input_shape, pooling, classes, **kwargs)
#     455     return stack1(x, 512, 3, name='conv5')
#     456
# --> 457   return ResNet(stack_fn, False, True, 'resnet50', include_top, weights,
#     458                 input_tensor, input_shape, pooling, classes, **kwargs)
#     459
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\applications\resnet.py in ResNet(stack_fn, preact, use_bias, model_name, include_top, weights, input_tensor, input_shape, pooling, classes, classifier_activation, **kwargs)
#     132
#     133   # Determine proper input shape
# --> 134   input_shape = imagenet_utils.obtain_input_shape(
#     135       input_shape,
#     136       default_size=224,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\applications\imagenet_utils.py in obtain_input_shape(input_shape, default_size, min_size, data_format, require_flatten, weights)
#     363           raise ValueError('`input_shape` must be a tuple of three integers.')
#     364         if input_shape[-1] != 3 and weights == 'imagenet':
# --> 365           raise ValueError('The input must have 3 channels; got '
#     366                            '`input_shape=' + str(input_shape) + '`')
#     367         if ((input_shape[0] is not None and input_shape[0] < min_size) or
#
# ValueError: The input must have 3 channels; got `input_shape=(224, 224, 32)`

# %%
with tf.device('/gpu:0'):
    
    '''
    baseModel = ResNet50(weights = "imagenet", include_top = False,
        input_tensor = Input(shape = second_layer.output.shape[1:]))
    '''
    
    n_epochs = 25
    
    
    baseModel = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(filters = 64, kernel_size = (2, 2), strides = 1, input_shape = second_layer.output.shape[1:]),
        tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3), strides = 1),
        tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3), strides = 1),
        tf.keras.layers.AveragePooling2D(pool_size = (2, 2))])
    
    
    headModel = baseModel.output
    headModel = AveragePooling2D(pool_size = (3, 3))(headModel)
    headModel = Flatten(name = "flatten")(headModel)
    headModel = Dense(512, activation = "relu")(headModel)
    headModel = Dropout(0.5)(headModel)
    headModel = Dense(len(lbBinarizer.classes_), activation = "softmax")(headModel)

    model = Model(inputs=baseModel.input, outputs=headModel)

    for layer in baseModel.layers:
        layer.trainable = False
    
    print("Compiling model:")
    opt = SGD(lr = 1e-4, momentum = 0.9, decay = (1e-4 / n_epochs))
    model.compile(loss = "categorical_crossentropy", optimizer = opt, metrics = [tf.keras.metrics.Accuracy(),
                                                                                 tf.keras.metrics.CategoricalAccuracy(),
                                                                                 tf.keras.metrics.TopKCategoricalAccuracy(),
                                                                                 tf.keras.metrics.Precision(),
                                                                                 tf.keras.metrics.Recall(), 
                                                                                 tf.keras.metrics.TruePositives(), 
                                                                                 tf.keras.metrics.TrueNegatives(), 
                                                                                 tf.keras.metrics.FalsePositives(), 
                                                                                 tf.keras.metrics.FalseNegatives()])

    '''
    print("Training head:")
    H = model.fit(
        x = trainAug.flow(trainX, trainY, batch_size = 32),
        steps_per_epoch = len(trainX) // 32,
        validation_data = valAug.flow(testX, testY),
        validation_steps = len(testX) // 32,
        epochs = n_epochs)
    
    
    H = model.fit(
        x = inputGenerator(4, x_train, True),
        steps_per_epoch = len(x_train) // 4,
        validation_data = inputGenerator(4, x_test, True),
        validation_steps = len(x_test) // 4,
        epochs = n_epochs)
    
    
    H = model.fit_generator(train_generator,
                           steps_per_epoch = batchSize,
                           epochs = n_epochs,
                           validation_data = test_generator,
                           validation_steps = batchSize)
    '''
    
    H = model.fit(train_generator, epochs = n_epochs, validation_data = test_generator)
# Out:
# Compiling model:
# C:\Users\Yash Umale\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-0579395b59c7> in <module>
#      65     '''
#      66
# ---> 67     H = model.fit(train_generator, epochs = n_epochs, validation_data = test_generator)
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1131          training_utils.RespectCompiledTrainableState(self):
#    1132       # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1133       data_handler = data_adapter.get_data_handler(
#    1134           x=x,
#    1135           y=y,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\data_adapter.py in get_data_handler(*args, **kwargs)
#    1362   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1363     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1364   return DataHandler(*args, **kwargs)
#    1365
#    1366
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1152     adapter_cls = select_data_adapter(x, y)
#    1153     self._verify_data_adapter_compatibility(adapter_cls)
# -> 1154     self._adapter = adapter_cls(
#    1155         x,
#    1156         y,
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     807     # Since we have to know the dtype of the python generator when we build the
#     808     # dataset, we have to look at a batch to infer the structure.
# --> 809     peek, x = self._peek_and_restore(x)
#     810     peek = self._standardize_batch(peek)
#     811     peek = _process_tensorlike(peek)
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\data_adapter.py in _peek_and_restore(x)
#     864   @staticmethod
#     865   def _peek_and_restore(x):
# --> 866     peek = next(x)
#     867     return peek, itertools.chain([peek], x)
#     868
#
# <ipython-input-5-3bf2951c0ad6> in inputMapGenerator(batch_size, arrPaths, lbls)
#      16                 batch_no += 1
#      17
# ---> 18                 X.append(getFusedData(batch_sample))
#      19                 Y.append(label)
#      20
#
# <ipython-input-4-8a7a06f7419a> in getFusedData(tenFrames)
#      12     batch_1_4 = np.stack(np.array(batch_4), axis = 0)
#      13
# ---> 14     out_1_1 = first_layer(batch_1_1)
#      15     out_1_2 = first_layer(batch_1_2)
#      16     out_1_3 = first_layer(batch_1_3)
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1011         training=training_mode):
#    1012
# -> 1013       input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#    1014       if eager:
#    1015         call_fn = self.call
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\keras\engine\input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     228       ndim = x.shape.rank
#     229       if ndim is not None and ndim < spec.min_ndim:
# --> 230         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#     231                          layer_name + ' is incompatible with the layer: '
#     232                          ': expected min_ndim=' + str(spec.min_ndim) +
#
# ValueError: Input 0 of layer sequential is incompatible with the layer: : expected min_ndim=4, found ndim=1. Full shape received: (4,)

# %%
# Evaluate the network
print("Evaluating network:")
predictions = model.predict(x = x_test.astype("float32"), batch_size = 32)

# To print precision, recall, F1 score
print(classification_report(y_test.argmax(axis = 1), predictions.argmax(axis = 1), target_names = lb.classes_))

# Plot the training loss and accuracy
N = n_epochs
plt.style.use("ggplot")

plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy on Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss/ Accuracy")
plt.legend(loc="lower left")

plotPath = r'C:\Users\Yash Umale\Documents\7th Sem\Research Paper\Plots'
plt.savefig(plotPath)

# %%
# Evaluate the network
print("Evaluating network:")
predictions = model.predict(x = x_test.astype("float32"), batch_size = 32)

# To print precision, recall, F1 score
print(classification_report(y_test.argmax(axis = 1), predictions.argmax(axis = 1), target_names = lb.classes_))

# Plot the training loss and accuracy
N = n_epochs
plt.style.use("ggplot")

plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy on Dataset")
plt.xlabel("Epoch #")
plt.ylabel("Loss/ Accuracy")
plt.legend(loc="lower left")

plotPath = r'C:\Users\Yash Umale\Documents\7th Sem\Research Paper\Plots'
plt.savefig(plotPath)

# %% [markdown]
# ## Understanding Slow Fusion via 3D-CNNs

# %%
# set the matplotlib backend so figures can be saved in the background
import matplotlib
matplotlib.use("Agg")

# import the necessary packages
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import argparse
import pickle
import cv2
import os
import random

# %%
# Calculate output feature map size

first_layer = tf.keras.models.Sequential([
    tf.keras.layers.Input((4, 3, 224, 224)),
    tf.keras.layers.Conv2D(filters = 8, kernel_size = (3, 3, 3), strides = 1),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D(pool_size = (2, 2))
])

second_layer = tf.keras.models.Sequential([
    # input_shape needs to be fixed
    tf.keras.layers.Conv2D(filters = 16, kernel_size = (3, 3), strides = 1, input_shape = first_layer.output.shape[1:]),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.AveragePooling2D(pool_size = (2, 2))
])

# %%
first_layer.summary()
second_layer.summary()
